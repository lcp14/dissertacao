# %%
import pandas as pd
import zipfile
import xml.etree.ElementTree as ET
import ntpath

# %%
autores = pd.read_csv('../datasets/autores/autores.csv',delimiter="|")

# %%
codinstituicoes = []
for i in autores[' path ']:
    path = '../'+i.strip()
    uid = ntpath.basename(path).split('.')[0]
    #print (folder,a)
    zip_ref = zipfile.ZipFile(path, 'r')
    zip_ref.extractall()
    zip_ref.close()
    #Lendo XML
    xmlTree = ET.parse('curriculo.xml')
    root = xmlTree.getroot()
    if 'DATA-ATUALIZACAO' in root.attrib.keys():
        data_atualizacao = root.attrib['DATA-ATUALIZACAO']
    for dados in root.iter('RESUMO-CV'):
        resumo = dados.attrib['TEXTO-RESUMO-CV-RH']
    for dados in root.iter('ENDERECO-PROFISSIONAL'):
        codInstituicao = dados.attrib['CODIGO-INSTITUICAO-EMPRESA']
        nomeInstituicao = dados.attrib['NOME-INSTITUICAO-EMPRESA']
    for dados in root.iter('DOUTORADO'):
        docCodInstituicao = dados.attrib['CODIGO-INSTITUICAO']
        docAnoInicio = dados.attrib['ANO-DE-INICIO']
        docAnoFim = dados.attrib['ANO-DE-CONCLUSAO']
    for dados in root.iter('POS-DOUTORADO'):
        posCodInstituicao = dados.attrib['CODIGO-INSTITUICAO']
        posAnoInicio = dados.attrib['ANO-DE-INICIO']
        posAnoFim = dados.attrib['ANO-DE-CONCLUSAO']
    for dados in root.iter('AREA-DE-ATUACAO'):
        area = dados.attrib['NOME-DA-AREA-DO-CONHECIMENTO']
        subarea = dados.attrib['NOME-DA-SUB-AREA-DO-CONHECIMENTO']
        esp = dados.attrib['NOME-DA-ESPECIALIDADE']
        table_area.append([uid,area,subarea,esp])
        #print(area +'->'+subarea+'->'+esp)
    for id_idioma,dados in enumerate(root.iter('IDIOMA')):
        desIdioma = dados.attrib['DESCRICAO-DO-IDIOMA']
        idioma = dados.attrib['IDIOMA']
        table_idioma.append([uid,id_idioma,uid+str(id_idioma),idioma,desIdioma])
    for dados in root.iter('INFORMACAO-ADICIONAL-INSTITUICAO'):
        #print(dados.attrib['CODIGO-INSTITUICAO'])
        codInstituicao2 = dados.attrib['CODIGO-INSTITUICAO']
        if codInstituicao == codInstituicao2:
            siglaInstituicao = dados.attrib['SIGLA-INSTITUICAO']
            if codInstituicao not in codinstituicoes:
                instituicao.append([codInstituicao,siglaInstituicao,nomeInstituicao])
                codinstituicoes.append(codInstituicao)
    table_autor.append([uid,data_atualizacao,resumo,docCodInstituicao,docAnoInicio,docAnoFim,posCodInstituicao,posAnoInicio,posAnoFim,codInstituicao])
# Out:
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento de Imagens
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Data Mining->
# Ciência da Computação->Sistemas de Computação->Computação Musical
# Ciência da Computação->Sistemas de Computação->Interação Humano Computador
# Ciência da Computação->Metodologia e Técnicas da Computação->Web Design
# Ciência da Computação->Informática na Educação->
# Engenharia Mecânica->->
# Ciência da Computação->IoT (Internet of Things)->
# Ciência da Computação->Comunicação Tempo-Real->
# Ciência da Computação->Sistemas de Computação->Rede de Computadores
# Ciência da Computação->Sistemas Distribuídos->
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->
# Engenharia Elétrica->Telecomunicações->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia Elétrica->->
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Lineares e Não-Lineares
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Automação Eletrônica de Processos Elétricos e Industriais
# Ciência da Computação->Extração de Conhecimento->
# Ciência da Computação->Mineração de Textos->
# Ciência da Computação->Mineração de Dados->
# Ciência da Computação->Epistemologia->
# Ciência da Computação->Ontologia->
# Ciência da Computação->Linguagens de Programação->
# Microeletrônica->->
# Ciência da Computação->Sistemas de Computação->Hardware
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->->
# Ciência da Computação->Processamento de imagens->
# Ciência da Computação->Computação natural->
# Ciência da Computação->Aprendizado de máquina->
# Ciência da Computação->Mineração de dados->
# Ciência da Computação->Computação Gráfica->Simulação
# Ciência da Computação->Computação Gráfica->Jogos
# Ciência da Computação->Sistemas de Computação->Educação à Distância
# Ciência da Computação->Computação Gráfica->Realidade Virtual
# Ciência da Computação->Computação Gráfica->Renderização de Cenas Tridimensionais
# Ciência da Computação->Computação Gráfica->Geometria Computacional
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Sistemas de Computação->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Controle de Processos Eletrônicos, Retroalimentação
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->
# Ciência da Computação->Sistemas de Computação->Banco de Dados
# Ciência da Computação->Sistemas de Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Teoria da Computação->Lógicas e Semântica de Programas
# Ciência da Computação->Computational Finance->
# Economia->Quantitative Finance->
# Ciência da Computação->Agent-Based Models->
# Ciência da Computação->Mathematical, Econometrical and Statistical Methods and Models->
# Ciência da Computação->Artificial Intelligence->
# Ciência da Computação->->
# Odontologia->->
# Administração->Auditoria, Fiscalização e Controle->
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Avaliação de Desempenho->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->Sistemas de Computação->Hardware
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Visão Computacional/Processamento de Imagens/Reconhecimento de Padrões->
# Ciência da Computação->Computação Gráfica/Realidade Virtual->
# Ciência da Computação->Desenvolvimento Web->
# Economia->->
# Agronomia->Extensão Rural->Transferência de Tecnologia
# Planejamento Urbano e Regional->->
# Agronomia->->
# Agronomia->Modelagem->
# Agronomia->Fitotecnia->Produção de Sementes e Mudas
# Ciência da Computação->Sistemas de Computação->Sistemas Inteligentes
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Geociências->Geofísica->Sensoriamento Remoto
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Criptografia->
# Ciência da Computação->Teoria dos Grafos->
# Ciência da Computação->Computação Bio-Inspirada->
# Ciência da Computação->Robótica->
# Ciência da Computação->Sistemas de Informação->Interação Humano Computador Ihc
# Ciência da Computação->Sistemas de Informação->Educação a Distância
# Ciência da Computação->Objetos de Aprendizagem (OAs)->
# Ciência da Computação->Ambientes Virtuais e Colaborativos para Ensino Aprendizagem (AVAs)->
# Ciência da Computação->Sistemas de Informação->Engenharia de Software
# Ciência da Computação->Sistemas de Informação->Sistemas de Informação Geográfica
# Engenharia Elétrica->Telecomunicações->Sistemas de Telecomunicações
# Geociências->Geofísica->Sensoriamento Remoto
# Geociências->Geofísica->Geofísica Aplicada
# Engenharia Elétrica->Engenharia de Sistemas->Sistemas e Computação
# Matemática->Matemática Aplicada->Redes Neurais
# Letras->Línguas Estrangeiras Modernas->Didática Especial da Língua Inglesa
# Saúde Coletiva->Epidemiologia->
# Geociências->Geoprocessamento->
# Ciência da Computação->Sistemas de Computação->Analise e Desenvolvimento de Sistemas de Informação
# Probabilidade e Estatística->Estatística->
# Ciência da Computação->Sistemas de Computação->Bancos de Dados
# Probabilidade e Estatística->Estatística->Análise de Dados
# Ciência da Computação->Sistemas de Computação->Reconhecimento de Padrões
# Ciência da Computação->Inteligência Artificial->Aprendizado de Máquinas
# Ciência da Computação->Processamento de Imagens->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Matemática da Computação->Matemática Simbólica
# Ciência da Computação->Sistemas de Computação->Software Aplicado
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Biologia Geral->teste registro->
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Engenharia de Software (Métodos Ágeis)->
# Ciência da Computação->Lógica Aplicada à Computação->
# Ciência da Computação->Inteligência Artificial->
# Física->Física Geral->
# Bioquímica->Biologia Molecular->BIOLOGIA MOLECULAR ESTRUTURAL
# Farmacologia->Farmacologia Bioquímica e Molecular->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Administração de sistemas
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia Mecânica->Fenômenos de Transporte->Princípios Variacionais e Métodos Numéricos
# Matemática->Matemática Aplicada->Análise Numérica
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Modelagem Computacional->
# Engenharia Biomédica->Modelos Analíticos e de Simulação->
# Engenharia Nuclear->Transporte de Partículas Neutras->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Matemática da Computação->
# Matemática->Matemática Aplicada->Matemática Discreta e Combinatória
# Física->Física Geral->Métodos Matemáticos da Física
# Física->Física Geral->Relatividade e Gravitação
# Física->Física das Partículas Elementares e Campos->Teoria Geral de Partículas e Campos
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Inteligência artificial->
# Ciência da Computação->Inteligência artificial->Engenharia do Conhecimento
# Ciência da Computação->Inteligência artificial->Modelagem Conceitual
# Ciência da Computação->Aprendizado de máquina->
# Ciência da Computação->Representação de conhecimento e raciocínio->
# Ciência da Computação->Robótica->
# Ciência da Computação->->Banco de Dados
# Ciência da Computação->Banco de Dados->Banco de Dados Complexos
# Ciência da Computação->->Sistemas de Informação
# Ciência da Computação->Engenharia de Software->Teste de Software
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Inteligência Artificial->Otimização
# Ciência da Computação->Inteligência Artificial->Aprendizagem de Máquina
# Ciência da Computação->Inteligência Artificial->Redes Neurais Artificiais
# Ciência da Computação->Inteligência Artificial->Agentes Inteligentes
# Probabilidade e Estatística->Estatística->
# Ciência da Computação->Ciência da Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Economia->Teoria Econômica->Economia Geral
# Economia->Teoria Econômica->Sistemas Econômicos
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Mineração de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->
# Engenharia de Produção->Pesquisa Operacional->
# Engenharia Biomédica->->
# Ciência da Computação->NEUROCIÊNCIA->
# Ciência da Computação->Sistemas de Computação->Processamento Digital de Imagens
# Ciência da Computação->Sistemas de Computação->Morfologia Matematica
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->
# Geociências->Geofísica->Sensoriamento Remoto
# Ciência da Informação->Arquivologia->Organização de Arquivos
# Ciência da Informação->Biblioteconomia->Técnicas de Recuperação de Informação
# Ciência da Computação->Redes de Computadores->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Segurança de Redes e de Dados->
# Ciência da Computação->Modelagem->
# Ciência da Computação->Sistemas Distribuídos->Rede de sensores sem fio
# Ciência da Computação->Sistemas Distribuídos->
# Ciência da Computação->Sistemas Distribuídos->Middleware
# Física->Áreas Clássicas de Fenomenologia e suas Aplicações->Acústica
# Engenharia Elétrica->Telecomunicações->Sistemas de Telecomunicações
# Engenharia Elétrica->Elétro-acústica->
# Ciência da Computação->Matemática da Computação->Processamento digital de sinais
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Eletrônicos
# Engenharia Elétrica->Medidas Elétricas, Magnéticas e Eletrônicas; Instrumentação->Instrumentação Eletrônica
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->->
# Geociências->->
# Ciência da Computação->Sistemas de Computação->Computer Networks
# Ciência da Computação->Metodologia e Técnicas da Computação->Aprendizagem Organizacional
# Lingüística->Filosofia da Linguagem->
# Ciência da Computação->Metodologia e Técnicas da Computação->Gestão do Conhecimento
# Administração->Administração de Setores Específicos->
# Ciência da Computação->Sistemas de Informação Geográfica->
# Ciência da Computação->Modelaje e Simulação->
# Planejamento Urbano e Regional->PLANEJAMENTO URBANO SUSTENTÁVEL->
# Engenharia de Produção->ENGENHARÍA INDUSTRIAL->
# Administração->Administração de Empresas->
# Administração->Administração de Empresas->Negócios Internacionais
# Ciência da Computação->Robótica Educacional->
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Teoria da Computação->Linguagem Formais e Autômatos
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Administração->->
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Redes de Computadores->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Teoria da Computação->Linguagem Formais e Autômatos
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Engenharia Mecânica->Engenharia Térmica->Aproveitamento da Energia
# Engenharia Mecânica->Engenharia Térmica->Termodinâmica
# Engenharia Mecânica->Engenharia Térmica->Combustão
# Engenharia Mecânica->Engenharia Térmica->Gaseificação
# Engenharia Mecânica->Engenharia Térmica->Controle Ambiental
# Ciência da Computação->Matemática da Computação->Matemática Simbólica
# Ciência da Computação->->
# Educação->->
# Biologia Geral->Bioinformática->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Inteligencia Artificial->Processamento da Linguagem Natural
# Ciência da Computação->Inteligencia Artificial->Recuperação de Informações
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Processamento de Imagens->Visão Computacional Aplicada
# Ciência da Computação->Processamento de Imagens->Visão Robótica
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia Elétrica->Controle & Automação->
# Engenharia Elétrica->Controle & Automação->Instrumentação, Interfaceamento de Sistemas
# Ciência da Computação->Metodologia e Técnicas da Computação->Redes Neurais Artificiais
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Sistemas Concorrentes->
# Ciência da Computação->Sistemas Reativos->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Informática na Educação->
# Engenharia de Produção->Midia e Conhecimento->Educação a Distância
# Ciência da Computação->Sistemas de Computação->Tecnologia Educacional
# Ciência da Computação->Interface Humano Computador->
# Ciência da Computação->sistemas colaborativos->
# Educação->Ensino-Aprendizagem->Métodos e Técnicas de Ensino Aprendizagem
# Educação->Ensino-Aprendizagem->Teorias da Aprendizagem
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Sistemas de Computação Aplicados à Educação e Treinamento->
# Matemática->Educação Matemática->
# Matemática->Geometria e Topologia->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Gestão do Conhecimento->
# Ciência da Computação->Aprendizagem Organizacional->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Sistemas de Segurança de Redes
# Ciência da Computação->Sistemas de Computação->Gerenciamento de Redes de Computadores
# Ciência da Computação->Metodologia e Técnicas da Computação->Redes de Computadores
# Ciência da Computação->Metodologia e Técnicas da Computação->Ensino de Computação
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Robótica, Mecatrônica e Automação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Administração->Administração de Empresas->Administração da Produção
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Robótica, Mecatrônica e Automação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Tolerância a Falhas
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Sistemas concorrentes, paralelos e distribuídos
# Ciência da Computação->Redes de Computadores->Redes de Sensores Sem Fio
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Administração->Administração de Empresas->
# Administração->Administração Pública->Organizações Públicas
# Direito->Direito Privado->Direito Autoral
# Direito->Direito Privado->Direito e Internet
# Direito->Direito Privado->Software
# Economia->Economia Industrial->Mudança Tecnológica
# Saúde Coletiva->Enfermagem do Trabalho->
# Saúde Coletiva->Saúde e Meio Ambiente->
# Ciência da Computação->Aprendizado de máquinas->
# Ciência da Computação->Biotecnologia->
# Engenharia Elétrica->Telecomunicações->Sistemas de Telecomunicações
# Artes->Música->Música e Tecnologia
# Lingüística->Psicolingüística->Percepção da Fala
# Ciência da Computação->Metodologia e Técnicas da Computação->Interface Homem Máquina
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Engenharia de Produção->Engenharia Econômica->
# Engenharia de Produção->Pesquisa Operacional->Modelagem, Simulação e Otimização
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia de Produção->Pesquisa Operacional->Inteligência Computacional
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->Extração de componentes a partir de uma mistura linear
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->Análise de Componentes Independentes em dados Multivariados
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->
# Ciência da Computação->Metodologia e Técnicas da Computação->Modelagem e Análise de Sistemas de Manufatura
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação Corporativos
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->->
# Ciência da Computação->Computação Bioinspirada->Algoritmos Genéticos
# Ciência da Computação->Bioinformática->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento de Imagens
# Ciência da Computação->->
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Matemática da Computação->
# Matemática->->
# Matemática->Análise->
# Matemática->Matemática Aplicada->
# Engenharia Biomédica->Bioengenharia->Modelagem de Sistemas Biológicos
# Fisiologia->Fisiologia de Órgãos e Sistemas->Fisiologia Cardiovascular
# Fisiologia->Fisiologia do Esforço->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Matemática->Matemática Aplicada->Análise Numérica
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Metodos Formais->Metodos Formais Aplicado Ao Projeto de Hardware
# Ciência da Computação->Metodos Formais->Metodos Formais Aplicado à Hardware Software Co Design
# Ciência da Computação->Navegação Autônoma de Robôs->
# Ciência da Computação->Metodologia e Técnicas da Computação->Computação Bio-inspirada
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Computacional
# Ciência da Computação->Navegação Autônoma de Robôs->Robótica Coletiva
# Ciência da Computação->Metodologia e Técnicas da Computação->Aprendizagem Artificial
# Ciência da Computação->Sistemas de Computação->Controle Inteligente
# Ciência da Computação->Cryptography->
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Matemática da Computação->
# Ciência da Computação->Bioinformática->
# Genética->Genética Humana e Médica->
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->REDES DE COMPUTADORES->
# Ciência da Computação->Segurança da Informação->
# Ciência da Computação->Governança de TI->
# Ciência da Computação->Sistemas Operacionais->
# Ciência da Computação->Hardware->
# Química->Química Orgânica->Estrutura, Conformação e Estereoquímica
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Química->Físico-Química->Espectroscopia
# Química->Química Orgânica->Química dos Produtos Naturais
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Genética->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas Reconfiguráveis
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas de Eventos Discretos
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Síntese Automática de Sistemas
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->
# Ciência da Computação->->
# Matemática->->
# Administração->->
# Ciência da Informação->->
# Letras->->
# Probabilidade e Estatística->->
# Ciência da Computação->Processamento Digital de Imagens->
# Ciência da Computação->Planejamento, Projeto e Controle de Sistemas de Produção->
# Ciência da Computação->Visão Computacional->
# Ciência da Computação->Robótica, Mecatrônica e Automação->
# Ciência da Computação->Desenvolvimento de Produto->
# Ciência da Computação->Ciência da Computação->
# Ciência da Computação->->
# Engenharia Elétrica->Telecomunicações->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Matemática da Computação->Criptologia
# Educação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Modelagem Computacional
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Ciência de dados->
# Ciência da Computação->Linguagens de Programação->
# Ciência da Computação->Banco de Dados->
# Ciência da Computação->Sistemas de Informação Geográfica->
# Filosofia->Filosofia da Lógica->
# Filosofia->Metafísica->
# Filosofia->Filosofia Analítica->
# Filosofia->Filosofia da Ciência e da Tecnologia->
# Filosofia->Ciências Ambientais->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Aprendizagem de Máquina->
# Ciência da Computação->Séries Temporais->
# Ciência da Computação->Redes Neurais->
# Administração->->
# Administração->Administração de Empresas->Administração de Recursos Humanos
# Administração->Administração de Empresas->Mercadologia
# Administração->Administração Pública->Contabilidade e Finanças Públicas
# Economia->Crescimento, Flutuações e Planejamento Econômico->Crescimento e Desenvolvimento Econômico
# Economia->Crescimento, Flutuações e Planejamento Econômico->Inflação
# Engenharia de Produção->Engenharia do Produto->Engenharia de Usabilidade
# Engenharia de Produção->Engenharia do Produto->Interação Humano Computador
# Ciência da Computação->Interface Homem Máquina->
# Desenho Industrial->Programação Visual->Projeto da Interface com o Usuário
# Desenho Industrial->Ergonomia->
# Ciência da Computação->Interface Homem Máquina->Interfaces Para Telefones Celulares
# Ciência da Computação->->
# Ciência da Computação->Teoria da Computação->Processamento de Língua Natural
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Ciência da Computação->->
# Ciência da Computação->Sistemas Distribuídos->
# Ciência da Computação->Sistemas Distribuídos->Grades Computacionais
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Engenharia Elétrica->Sistemas Embutidos->
# Engenharia Elétrica->Sistemas de Computação Integrados->
# Engenharia Elétrica->Internet das Coisas->
# Engenharia Elétrica->Sistemas VLSI->
# Engenharia Elétrica->Programação->
# Engenharia Elétrica->Engenharia Elétrica->
# Ciência da Computação->Metodologia e Técnicas da Computação->Interação Humano-Computador
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Educação->Ensino-Aprendizagem->Métodos e Técnicas de Ensino
# Ciência da Computação->Informática na Educação->
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Visão Computacional->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Hardware
# Geociências->Geoprocessamento->
# Geociências->Geofísica->Sensoriamento Remoto
# Geociências->Planejamento Agrícola e Ambiental->
# Geociências->Sistema de Informação Geográfica->Sistema de Informação Geográfica- Análise Espacial
# Geociências->Land Use Change Monitoring->Land Use Change Monitoring and Modelling
# Geociências->Biofuel->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Informação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Probabilidade e Estatística->Estatística->Análise de Dados
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->
# Ciência da Computação->Metodologia e Técnicas da Computação->Teste de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Ciência da Computação->Teoria da Computação->Linguagem Formais e Autômatos
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistema Embarcado de Tempo Real
# Ciência da Computação->Sistemas de Informação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Sistemas Embarcados e Computação Ubíqua
# Ciência da Computação->Sistemas de Computação->Desenvolvimento Web
# Ciência da Computação->Computação Visual->
# Ciência da Computação->Computação Gráfica->
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Geometria Computacional->
# Ciência da Computação->Computação Forense->
# Ciência da Computação->Métodos de otimização não-linear->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Educação->Currículo->Teoria Geral de Planejamento e Desenvolvimento Curricular
# Ciência da Computação->Metodologia e Técnicas da Computação->TECNOLOGIA DE ENSINO A DISTÂNCIA
# Ciência da Computação->Sistemas de Computação->Multimídia
# Ciência da Computação->Sistemas de Computação->Informática na Educação
# Ciência da Computação->Sistemas de Computação->Inteligência Artificial
# Ciência da Computação->Sistemas de Computação->Informática Em Saúde
# Ciência da Computação->Sistemas de Computação->Realidade Virtual
# Ciência da Computação->Sistemas de Computação->Desenvolvimento de Software Aplicativo
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Engenharia Nuclear->Tecnologia dos Reatores->Instrumentação para Operação e Controle de Reatores
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Robótica, Mecatrônica e Automação->Robotica Móvel->
# Ciência da Computação->Metodologia e Técnicas da Computação->Hipermídia Educacional
# Ciência da Computação->Matemática da Computação->Matemática Simbólica
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas para Web
# Ciência da Computação->Metodologia e Técnicas da Computação->Bioinformática
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Teoria da Computação->Lógica Fuzzy
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Microprocessadores
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Teoria da Computação->Lógicas e Semântica de Programas
# Matemática->Álgebra->Lógica Matemática
# Ciência da Computação->Logica Universal->
# Ciência da Computação->Inteligencia Artificial->
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->Modelos Analíticos e de Simulação
# Ciência da Computação->Educação Superior->Cursos de Graduação
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Engenharia Biomédica->Bioengenharia->Processamento de Sinais Biológicos
# Ciência da Computação->Reconocimiento de Patrones->
# Ciência da Computação->Inteligencia Artificial->
# Engenharia Elétrica->Sistemas Elétricos de Potência->
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Teoria Geral dos Circuitos Elétricos
# Engenharia Elétrica->Telecomunicações->Processamento Digitais de Fala
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Algoritmos e Estruturas de Dados->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Docência
# Administração->Administração de Empresas->
# Ciência da Computação->Metodologia e Técnicas da Computação->GESTÃO DE PROCESSOS
# Ciência da Computação->Metodologia e Técnicas da Computação->SISTEMA DA QUALIDADE
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas Embarcados
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Automação Eletrônica de Processos Elétricos e Industriais
# Ciência da Computação->->
# Ciência da Computação->Educação à Distância->
# Educação->Tópicos Específicos de Educação->Informática Aplicada à Educação
# Ciência da Computação->Interação Humano Computador->
# Ciência da Computação->Web Social->
# Ciência da Computação->Web Semântica->
# Ciência da Computação->Ontologias->
# Ciência da Computação->Sistemas de Conhecimento->
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Sistemas de Conhecimento->Governo Eletrônico
# Ciência da Computação->Sistemas de Conhecimento->Memória e Aprendizagem Organizacional
# Ciência da Computação->Matemática da Computação->Cálculo Numérico Computacional
# Ciência da Computação->Tecnologia de Informação->
# Ciência da Computação->->
# Engenharia Civil->Estruturas->Estruturas de Concreto
# Engenharia Civil->Engenharia Hidráulica->Hidrologia
# Engenharia Civil->Engenharia Hidráulica->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Engenharia Cartografica->->
# Planejamento Urbano e Regional->->
# Ciência da Computação->Redes Veiculares->
# Ciência da Computação->Redes de Computadores->
# Ciência da Computação->Computação Distribuída->
# Ciência da Computação->Sistemas Operacionais->
# Ciência da Computação->Sistemas de Informação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Requisitos de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Engenharia de Produção->Gerência de Produção->Gestão da Informação
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Desenvolvimento Distribuído de Software->
# Engenharia de Produção->Gerência de Produção->
# Engenharia de Produção->Gerência de Produção->Planejamento, Projeto e Controle de Sistemas de Produção
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Engenharia de Produção->Engenharia do Produto->
# Ciência da Computação->Sistemas de Computação->
# Química->Química Analítica->Instrumentação Analítica
# Química->Química Analítica->Métodos Óticos de Análise
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Matemática->Matemática Aplicada->
# Ciência da Computação->Metodologia e Técnicas da Computação->Otimização
# Engenharia Mecânica->Engenharia Térmica->Termodinâmica
# Ciência da Computação->Informática e Educação->
# Ciência da Computação->Lógica e Representação de Conhecimento->
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas Distribuídos->
# Ciência da Computação->Computação Gráfica e Visualização de Software->
# Ciência da Computação->Software Livre->
# Ciência da Computação->Mecatrônica->Sistemas de Tempo-Real
# Ciência da Computação->Segurança Cibernética->
# Ciência da Computação->Engenharia de Software->
# Ciência da Computação->Sistemas de Informação->
# Ciência da Computação->Ciência da Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Apoio a Decisão
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Inteligência Artificial->Sistemas Nebulosos
# Ciência da Computação->Inteligência Artificial->Aquisição do Conhecimento
# Ciência da Computação->Inteligência Artificial->Mineração de Dados Em Banco de Dados
# Ciência da Computação->->
# Ciência da Computação->REDES DE TELECOMUNICAÇÕES->
# Ciência da Computação->SISTEMAS DE INFORMAÇÃO->
# Ciência da Computação->Redes de Computadores->
# Biologia Geral->Bioinformática->
# Ciência da Computação->Redes sem Fio->
# Biologia Geral->Biotecnologia Aplicada->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Arquitetura de Software->
# Ciência da Computação->Linguagens de Programação->
# Ciência da Computação->Banco de Dados->
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Matemática da Computação->Matemática Simbólica
# Ciência da Computação->Sistemas de Computação->
# Engenharia Elétrica->Medidas Elétricas, Magnéticas e Eletrônicas; Instrumentação->Sistemas Eletrônicos de Medida e de Controle
# Engenharia Elétrica->Telecomunicações->Teoria Eletromagnetica, Microondas, Propagação de Ondas, Antenas
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Computação Científica->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Consultas Visuais
# Ciência da Computação->Metodologia e Técnicas da Computação->Interfaces Homem Máquina
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informações Geográficas
# Ciência da Computação->Sistemas de Computação->Ontologias
# Ciência da Computação->Algoritmos e Grafos->
# Ciência da Computação->Representação de Álgebras->
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Matemática da Computação->Lógica Matemática
# Ciência da Computação->SISTEMAS DE INFORMAÇÃO->
# Ciência da Computação->SISTEMAS DE INFORMAÇÃO->Programação
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->Sistemas Distribuídos
# Ciência da Computação->Sistemas de Computação->Algoritmos Distribuídos
# Ciência da Computação->Sistemas de Computação->Tolerância a Falhas
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Ciência da Computação->Consenso Distribuído->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Artes->->
# Artes->Artes do Vídeo->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Artes->Fundamentos e Crítica das Artes->Crítica da Arte
# Letras->->
# Matemática->->
# Ciência da Computação->Sistemas de Computação->
# Física->->
# Turismo->->
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Software Básico
# Matemática->Álgebra->Lógica Matemática
# Ciência da Computação->Matemática da Computação->Matemática Simbólica
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Redes de Computadores
# Administração->habitats de inovação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->->
# Ciência da Computação->Informática na Educação->Educação à Distância
# Ciência da Computação->Informática na Educação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia Elétrica->Telecomunicações->Sistemas de Telecomunicações
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Eletrônicos
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Direito->Direito Privado->Direito do Trabalho
# Direito->Direito Privado->Direito Comercial
# Direito->Direito Privado->Direito Civil
# Direito->Direito Público->Direito Processual Civil
# Direito->Direito Público->Direito Administrativo
# Direito->Direito Público->Direito Constitucional
# Engenharia Sanitária->Saneamento Básico->Técnicas de Abastecimento da Água
# Engenharia Sanitária->Saneamento Ambiental->Modelagem Numérica
# Ciência da Computação->Matemática da Computação->Otimização
# Engenharia Sanitária->Gestão no Saneamento->
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Educação->Ensino-Aprendizagem->
# Educação->Tópicos Específicos de Educação->Educação Especial
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento de Imagens
# Ciência da Computação->Reconhecimento de padrões->
# Ciência da Computação->Teoria dos grafos->
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Divulgação Científica->
# Ciência da Computação->Metodologia e Técnicas da Computação->Aprendizado de Máquina
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Educação->Tópicos Específicos de Educação->Educação em saúde
# Ciência da Computação->Sistemas de Computação->Informática na educação
# Educação->Mobile Learning->
# Educação->Informática em saúde->
# Educação->Saúde Materno-Infantil->
# Educação->Educação->
# Comunicação->Comunicação Integrada->
# Administração->Administração Pública->
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Engenharia Elétrica->Processamento Digital de Sinais->Reconhecimento de Padrões
# Engenharia de Transportes->Planejamento de Transportes->Planejamento e Organização do Sistema de Transporte
# Engenharia Elétrica->Telecomunicações->Processamento Digital de Sinais
# Engenharia Elétrica->Telecomunicações->Sistemas de Telecomunicações
# Engenharia Elétrica->Medidas Elétricas, Magnéticas e Eletrônicas; Instrumentação->Instrumentação Eletrônica
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Saúde Coletiva->Epidemiologia->
# Probabilidade e Estatística->Estatística->
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Bioética->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Desenvolvimento de Software Orientado a Aspectos
# Ciência da Computação->Metodologia e Técnicas da Computação->Programação Generativa
# Ciência da Computação->Metodologia e Técnicas da Computação->Linhas de Produto de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Teoria da Computação->
# Administração->Administração de Empresas->Tecnologia da Informação
# Administração->Administração Pública->Planejamento em Ciência e Tecnologia
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->->
# Ciência da Computação->Processamento de Imagens->
# Administração->Administração de Empresas->Logística
# Engenharia de Transportes->Planejamento de Transportes->Planejamento e Organização do Sistema de Transporte
# Engenharia de Transportes->Operações de Transportes->Operação de Sistemas de Transporte
# Engenharia de Produção->Pesquisa Operacional->
# Ciência da Computação->Machine Learning->
# Medicina->Neuroimaging->
# Medicina->Neuroscience->
# Farmácia->ASSISTÊNCIA FARMACÊUTICA->
# Farmácia->ATENÇÃO FARMACÊUTICA->
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Sistemas de Computação->
# Filosofia->Epistemologia->
# Filosofia->Lógica->
# Filosofia->História da Filosofia->
# Ciência da Informação->Teoria da Informação->
# Ciência da Computação->Sistemas de Computação->Segurança Digital
# Ciência da Computação->Sistemas de Computação->Interface Social da Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Sistemas de Computação->Redes de Computadores
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Probabilidade e Estatística->Probabilidade->Teoria Geral e Fundamentos da Probabilidade
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Hardware
# Ciência da Computação->Informática na Educação->
# Ciência da Computação->Engenharia de Software->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Estrutura de dados
# Ciência da Computação->Bioinformática->
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Inteligência Artificial->Processamento da Língua Natural
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Engenharia de Software->Engenharia de Requisitos
# Ciência da Computação->Engenharia de Software->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas Embarcados
# Ciência da Computação->Sistemas Críticos->
# Ciência da Computação->Robótica Móvel->
# Agronomia->Fitotecnia->Estatística
# Agronomia->Fitotecnia->
# Agronomia->Fitotecnia->Melhoramento Vegetal
# Agronomia->Agrometeorologia->
# Matemática->->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Computação->Hardware
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Eletrônicos
# Ciência da Computação->Metodologia e Técnicas da Computação->Interação Humano Computador
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Sistemas de Computação->Redes de Sensores Sem Fio
# Ciência da Computação->->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas reconfiguráveis
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Sistemas embarcados
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# ...
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->->
# Biofísica->Biofísica de Processos e Sistemas->
# Física->->
# Administração->Administração de Empresas->Gestão de Projetos
# Engenharia Elétrica->->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Engenharia Biomédica->Ciencias da Computação->
# Engenharia Biomédica->Bioengenharia->Processamento de Imagens Médicas
# Engenharia Biomédica->->
# Engenharia Biomédica->Bioengenharia->Processamento de Sinais Biológicos
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Eletrônicos
# Ciência da Computação->Informática->Processamento digital de imagem
# Ciência da Computação->Visão por Computador->
# Ciência da Computação->Inteligencia Computacional->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Desenho Industrial->Programação Visual->
# Desenho Industrial->Desenho de Produto->
# Ciência da Computação->Sistemas de Computação->Processamento Digital de Imagens
# Ciência da Computação->Sistemas de Computação->Sistemas Inteligentes
# Engenharia Biomédica->Engenharias IV->
# Engenharia Biomédica->Linguagens de Programação->
# Engenharia Biomédica->Lógicas e Semântica de Programas->
# Engenharia Biomédica->Análise de Algoritmos e Complexidade de Computação->
# Divulgação Científica->Inovação tecnologica->
# Ciência da Computação->Inteligencia Artificial->
# Ciência da Computação->Recommender systems->
# Ciência da Computação->Affective computing->
# Ciência da Computação->Informática na Educação->
# Multidisciplinar->Metrologia->
# Engenharia Elétrica->Inteligência Computacional Aplicada->
# Engenharia Biomédica->->
# Engenharia Elétrica->Medidas Elétricas, Magnéticas e Eletrônicas; Instrumentação->
# Física->Supercondutividade Aplicada e Magnetismo->
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Matemática da Computação->Modelagem e simulação de nanoestruturas
# Ciência da Computação->Metodologia e Técnicas da Computação->Geometria Computacional
# Medicina->Anatomia Patológica e Patologia Clínica->Patologia Feto Placentária
# Medicina->Saúde Materno-Infantil->Informática Aplicada à Saúde da Criança
# Medicina->Anatomia Patológica e Patologia Clínica->Análise de Imagens Em Patologia
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Sistemas de Computação->Hardware
# Engenharia Elétrica->Eletrônica Industrial, Sistemas e Controles Eletrônicos->Robótica
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->Robótica
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Computacional
# Ciência da Computação->Sistemas de Computação->Sistemas Embarcados e Microcontroladores
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Ciência da Computação->Sistemas de Computação->Gerência de Redes
# Ciência da Computação->Sistemas de Computação->Computação em Grades
# Ciência da Computação->Sistemas de Computação->Sistemas Distribuídos
# Ciência da Computação->Redes de Computadores->
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Sistemas de Computação->Software Básico
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Biologia Geral->NEUROCIÊNCIAS->
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Informática na Educação->Ensino de Ciências e Matemática
# Ciência da Computação->Informática na Educação->
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Interação Homem Computador->
# Ciência da Computação->TECNOLOGIA DA INFORMAÇÃO->
# Ciência da Informação->Biblioteconomia->Técnicas de Recuperação de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento de Imagem
# Ciência da Computação->Recuperação de Informação com Base no Conteúdo->
# Ciência da Computação->Redes Complexas->
# Ciência da Computação->Telemedicina e Informática na Saúde->
# Administração->Administração de Empresas->Administração da Produção
# Engenharia de Produção->Gerência de Produção->Planejamento, Projeto e Controle de Sistemas de Produção
# Engenharia de Produção->Dinâmica de Sistemas->
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Engenharia de Produção->Inteligência Artificial->
# Engenharia de Produção->Sistemas de Informação->
# Ciência da Computação->Teoria da Computação->
# Ciência da Computação->Teoria da Computação->Logica aplicada a computacao
# Engenharia Elétrica->Sistemas Elétricos de Potência->Transmissão da Energia Elétrica, Distribuição da Energia Elétrica
# Ciência da Computação->Inteligência Artificial->
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Sistemas de Computação->Hardware
# Ciência da Computação->Sistemas Operacionais->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->games->
# Ciência da Computação->realidade virtual->
# Ciência da Computação->Modelos Analíticos e de Simulação->
# Ciência da Computação->->
# Ciência da Computação->Engenharia de Software->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Metodologia e Técnicas da Computação->Realidade Virtual
# Ciência da Computação->Metodologia e Técnicas da Computação->Realidade Aumentada
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Arquitetura de Software
# Ciência da Computação->Sistemas-de-Sistemas->
# Engenharia Elétrica->Circuitos Elétricos, Magnéticos e Eletrônicos->Circuitos Eletrônicos
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Sistemas de Computação->Sistemas Distribuídos
# Ciência da Computação->Metodologia e Técnicas da Computação->Avaliação de Desempenho
# Ciência da Computação->Sistemas de Computação->Arquitetura e Aplicações da Web
# Ciência da Computação->Sistemas de Computação->Multimídia
# Educação->->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Sistemas de Computação->Realidade Aumentada
# Ciência da Computação->Metodologia e Técnicas da Computação->Visão Computacional
# Engenharia Elétrica->Fusão sensorial, visão computacional, robótica->
# Engenharia Elétrica->Recuperação de informação visual->
# Engenharia Elétrica->Processamento Gráfico (Graphics)->
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial - Web Semântica
# Ciência da Computação->Recuperação da Informação->
# Medicina->Informática médica->
# Ciência da Computação->Telemedicina->
# Zootecnia->Produção Animal->Gestão de sistemas de produção animal
# Zootecnia->Produção Animal->
# Administração->Administração de Empresas->Administração Financeira
# Ciência da Computação->Sistemas de Computação->Teleinformática
# Educação->Ensino-Aprendizagem->Tecnologia Educacional
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->->
# Ciência da Computação->Banco de Dados->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento de Imagens
# Ciência da Computação->Metodologia e Técnicas da Computação->Banco de Dados
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Raciocínio Baseado em Casos->
# Ciência da Computação->Agentes Inteligentes->
# Ciência da Computação->Sistemas de Computação->Sistemas de Informação Geográficos
# Ciência da Computação->Sistemas de Informação Geográficos->Bancos de Dados Espaciais
# Ciência da Computação->Sistemas de Computação->Engenharia de Software
# Ciência da Computação->Sistemas de Computação->Desenvolvimento de Sistemas
# Ciência da Computação->Sistemas de Computação->Arquitetura de Sistemas de Computação
# Ciência da Computação->Sistemas de Informação Geográficos->Geometria Computacional
# Ciência da Computação->Metodologia e Técnicas da Computação->Gerenciamento de Projetos
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Estudos do Futuro->
# Ciência da Computação->Engenharia de Software->
# Ciência da Computação->Empreendedorismo->
# Ciência da Computação->Linguagens de Programação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Ciência da Computação->Sistemas de Computação->Modelagem Computacional de Processos de Meio Ambiente
# Ciência da Computação->Metodologia e Técnicas da Computação->Microeletrônica
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->Engenharia de Software
# Ciência da Computação->->
# Administração->->
# Ciência da Computação->->
# Matemática->->
# Física->->
# Educação->->
# Administração->->
# Geociências->->
# Probabilidade e Estatística->->
# Ciência da Computação->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Educação->->
# Educação->Orientação e Aconselhamento->
# Sociologia->->
# Comunicação->->
# Letras->->
# Psicologia->->
# Artes->Fotografia->
# Desenho Industrial->Programação Visual->
# Comunicação->Jornalismo e Editoração->
# Ciência da Computação->Comunicação Online->
# Comunicação->Produção cultural->
# Artes->Estética e Artes Visuais->
# Ciência da Computação->Matemática da Computação->Modelos Analíticos e de Simulação
# Engenharia de Produção->Pesquisa Operacional->
# Probabilidade e Estatística->->
# Engenharia de Produção->->
# Engenharia de Produção->Gestão da Tecnologia->Inovação Tecnológica e Organizacional
# Ciência da Computação->Inteligência Artificial->Engenharia do Conhecimento
# Engenharia de Produção->Estratégia Tecnologia e Organização->
# Engenharia de Produção->Gestão da Tecnologia->Gestão do Conhecimento
# Engenharia de Produção->Gestão da Tecnologia->
# Engenharia de Produção->Tecnologia da Informação e Comunicação->
# Ciência da Computação->Inteligência Artificial->Processamento da Língua Natural
# Lingüística->Lingüística Aplicada->Lingüística Computacional
# Letras->Língua Portuguesa->
# Ciência da Computação->Inteligência Artificial->
# Lingüística->Filosofia da Linguagem->
# Ciência da Computação->->
# Educação Física->->
# Ciência da Computação->Metodologia e Técnicas da Computação->Engenharia de Software
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Integração de Sistemas->Integração de Sistemas
# Ciência da Computação->->
# Matemática->Modelagem e simulação computacional->
# Matemática->Sistemas Dinâmicos->
# Matemática->Teoria dos Jogos->
# Matemática->Teoria dos Grafos->
# Matemática->Análise Numérica->
# Engenharia Biomédica->Bioengenharia->Modelagem de Sistemas Biológicos
# Ciência da Computação->Sistemas de Informação->Gerência de Projetos
# Ciência da Computação->Sistemas de Informação->
# Ciência da Computação->Engenharia de Software->
# Ciência da Computação->Tecnologia da Informação->
# Ciência da Computação->Teoria da Computação->Inteligência Artificial
# Ciência da Computação->Complexidade Computacional->
# Ciência da Computação->Busca Heurística->
# Ciência da Computação->Planejamento Clássico->
# Ciência da Computação->Jogos e Puzzles->
# Ciência da Computação->->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Sistemas de Computação->
# Ciência da Computação->Matemática da Computação->
# Geociências->Cartografia->
# Ciência da Computação->Ciências->
# Ciência da Computação->Ciências->Processamento da Informação
# Ciência da Computação->->
# Engenharia Biomédica->->
# Engenharia Elétrica->->
# Ciência da Computação->Matemática da Computação->
# Ciência da Computação->Matemática da Computação->Computação Gráfica
# Ciência da Computação->Matemática da Computação->Processamento de Imagens
# Ciência da Computação->Matemática da Computação->Visualização Científica
# Ciência da Computação->Teoria da Computação->Computabilidade e Modelos de Computação
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Metodologia e Técnicas da Computação->Processamento Gráfico (Graphics)
# Ciência da Computação->Informática e Sociedade->
# Ciência da Computação->Sistemas de Computação->Redes de Computadores
# Ciência da Computação->Sistemas de Computação->Recuperação de Informação
# Ciência da Computação->Sistemas de Computação->Mineração de Dados
# Ciência da Computação->Sistemas de Computação->Aprendizagem de Máquina
# Ciência da Computação->Metodologia e Técnicas da Computação->Sistemas de Informação
# Ciência da Computação->Processamento de Linguagem Natural->
# Ciência da Computação->->
# Ciência da Computação->Engenaria Biomedica->Simulação
# Ciência da Computação->Metodologia e Técnicas da Computação->Linguagens de Programação
# Engenharia Biomédica->->
# Ciência da Computação->Engenaria Biomedica->Realidade Virtual
# Ciência da Informação->Biblioteconomia->Organização do Conhecimento
# Lingüística->Lingüística Aplicada->Teoria da Terminologia
# Ciência da Informação->Teoria da Informação->Representação da Informação
# Ciência da Informação->Teoria da Informação->Teoria Geral da Informação
# Ciência da Informação->Biblioteconomia->
# Ciência da Computação->Sistemas de Computação->Tecnologia e Programacao Em Cluster
# Ciência da Computação->Sistemas de Computação->Sistemas Operacionais e Distribuidos
# Ciência da Computação->Sistemas de Computação->Informática
# Ciência da Computação->Vida Artificial->
# Ciência da Computação->Metodologia e Técnicas da Computação->Inteligência Artificial
# Ciência da Computação->Metodologia e Técnicas da Computação->Computação Gráfica
# Ciência da Computação->Inteligência artificial->
# Ciência da Computação->Metodologia e Técnicas da Computação->
# Ciência da Computação->Teoria da Computação->
# Engenharia de Produção->Pesquisa Operacional->
# Engenharia de Produção->Engenharia Econômica->
# Engenharia de Produção->Engenharia do Produto->
# Ciência da Computação->Metodologia e Técnicas da Computação->Recuperação e Tratamento Textual
# Ciência da Computação->Metodologia e Técnicas da Computação->Aprendizado Por Máquina
# Ciência da Computação->Teoria da Computação->Análise de Algoritmos e Complexidade de Computação
# Probabilidade e Estatística->Probabilidade e Estatística Aplicadas->
# Ciência da Computação->Sistemas de Computação->Software Básico
# Engenharia Elétrica->COMPUTAÇÃO->

# %%
pd.DataFrame(table_autor[1:],columns=table_autor[0]).to_csv('autor_info.csv',index=False,sep='|')
pd.DataFrame(table_idioma[1:],columns=table_idioma[0]).to_csv('idioma.csv',index=False,sep='|')
pd.DataFrame(instituicao[1:],columns=instituicao[0]).to_csv('instituicoes.csv',index=False,sep='|')
pd.DataFrame(table_area[1:],columns=table_area[0]).to_csv('autor_area.csv',index=False,sep='|')

# %%
table_autor = [['id_autor','data_atualizacao','resumo','docCodInstituicao','docAnoInicio','docAnoFim','posCodInstituicao','posAnoInicio','posAnoFim','codInstituicao']]

# %%
len(table)
# Out:
# 11

# %%
table_idioma = [['id_autor','id_idioma','link','idioma','desIdioma']]

# %%
instituicao = [['codInstituicao','sigla','nomeInstituicao']]

# %%
table_area = [['id_autor','area','subarea','esp']]

# %%
table_autor
# Out:
# ['id_autor',
#  'data_atualizacao',
#  'resumo',
#  'docCodInstituicao',
#  'docAnoInicio',
#  'docAnoFim',
#  'posCodInstituicao',
#  'posAnoInicio',
#  'posAnoFim',
#  'codInstituicao',
#  ['96913881679975',
#   '03042018',
#   'É Tecnólogo em Processamento de Dados pela Universidade Federal do Pará (1990), obteve seu mestrado e doutorado em Ciência da Computação (Inteligência Artificial Aplicada) no Kyushu Institute of Technology no Japão, respectivamente em 1995 e 1998. Foi pesquisador visitante e fez estágio pós-doutorado na Universidade Johns Hopkins, EUA. Atualmente é tecnologista sênior do Instituto Nacional de Pesquisas Espaciais atuando em pesquisa e desenvolvimento em aplicações de inteligência artificial (data mining, processamento de imagens, sistemas inteligentes, técnicas e aplicações de big data/e-science). Autor do livro Introdução à Programação Orientada a Objetos usando Java, em sua segunda edição, publicado como parte da Coleção Campus/SBC.',
#   '000400000997',
#   '1995',
#   '1998',
#   '001700000990',
#   '2015',
#   '2016',
#   '008700000009'],
#  ['23958115215905',
#   '28122017',
#   'Bacharel em Informática. Possui Mestrado e Doutorado em Ciências da Computação pelo Programa de Pós-Graduação em Computação - PPGC, Universidade Federal do Rio Grande do Sul em 2004 e 2009, respectivamente. Realizou Estágio de Doutorado no exterior na Université Paris-Sud 11, em Paris. Atualmente é professor efetivo da área de Informática e Tecnologia da Informação no Instituto Federal de Educação, Ciência e Tecnologia - IFRS, Campus Porto Alegre, no Mestrado Profissional em Informática na Educação, Tecnólogo em Sistemas para a Internet e Curso Técnico em Instrumentos Musicais. As áreas de pesquisa de interesse incluem Design de Interação, Tecnologia de Informação e Comunicação e Computação Musical. Outras atividades acadêmicas incluem participação em bancas de especialização e projetos de cooperação internacional dentro dos programas CAPES-GRICES (Portugal), CAPES-COFECUB (França), CEGEP de Sherbrooke (Canadá) e participação em comitês de programa técnicos como o do Simpósio Brasileiro de Computação Musical - SBCM e Simpósio Brasileiro de Informática na Educação - SBIE, eventos da Sociedade Brasileira de Computação. Participação no Programa de Intercâmbio de Professores da SETEC/MEC no Québec, Canadá - acompanhamento de práticas de pesquisa aplicada e inovação em 2014.',
#   '019200000005',
#   '2005',
#   '2009',
#   '001700000990',
#   '2015',
#   '2016',
#   'IZEO00000008'],
#  ['44364437159422',
#   '08052013',
#   'Possui graduação em Engenharia Mecânica pela Universidade Federal de Santa Catarina (2004), mestrado em Engenharia Mecânica pela Universidade Federal de Santa Catarina (2006) e doutorado em Dr. sc. ETH Zurich - Swiss Federal Institute of Technology Zurich (2012). Tem experiência na área de Engenharia Mecânica, com ênfase em Processos de Fabricação',
#   '288900000003',
#   '2006',
#   '2012',
#   '001700000990',
#   '2015',
#   '2016',
#   ''],
#  ['12195457575500',
#   '28032018',
#   'Possui graduação em Informática (2002) e especialização em Redes e Sistemas Distribuídos (2005) pela Universidade do Planalto Catarinense, mestrado em Engenharia de Automação e Sistemas pela Universidade Federal de Santa Catarina (2008) e doutorado em Engenharia Informática pela Faculdade de Engenharia da Universidade do Porto - Portugal (2013). Atualmente é professor no IFSC (Instituto Federal de Santa Catarina) no Campus de Lages/SC. Tem experiência na área de Ciência da Computação e Engenharia de Automação, com ênfase em Rede de Computadores e Redes de Comunicação Industriais, atuando principalmente nos seguintes temas: Comunicação de Tempo-Real, Redes Industriais, Internet das Coisas e Indústria 4.0.',
#   '000900000996',
#   '2009',
#   '2013',
#   '001700000990',
#   '2015',
#   '2016',
#   '319000000000'],
#  ['96441655292018',
#   '27102017',
#   'Doutora em Engenharia e Tecnologia Espaciais pelo Instituto Nacional de Pesquisas Espaciais (2017). Recentemente realizou sanduíche na University of New Mexico (UNM) nos Estados Unidos da América, cujo trabalho foi premiado no 2015 Pulsed Power Conference como melhor artigo de estudante. Possui mestrado em Engenharia e Tecnologia Espaciais com concentração em Engenharia e Gerenciamento de Sistemas Espaciais - INPE (2013). Graduada em Tecnologia em Telecomunicações pela Universidade Estadual de Campinas - UNICAMP (2010). Possui curso técnico em Administração pelo Centro Paula Souza (2005). Possui conhecimentos sobre sólitons, linhas de transmissão não lineares, geração de radiofrequência de alta potência, indutores saturados, capacitores não lineares e diodos varactores com o auxílio de programas como: Origin, Matlab, Mathematica, Circuit Maker e LT-Spice. Atualmente trabalha com pesquisa relacionada ao estudo de linhas de transmissão não lineares giromagnéticas para aplicações aeroespaciais.',
#   '008700000009',
#   '2013',
#   '2017',
#   '769300000008',
#   '2017',
#   '',
#   '008700000009'],
#  ['91483000525292',
#   '23102017',
#   'Doutorado (2017) e Mestrado (2011) pela COPPE/UFRJ em Sistemas Computacionais, com ênfase em Ontologias e \nMineração de Textos. Graduação em Filosofia pela UFRJ-Universidade Federal do Rio de Janeiro (2002). \n\nExperiência na área de Ciência da Computação com ênfase em Linguagens de Programação, Sistemas de Informação \ne Text Analytics. \n\nInteresse em projetos, estudos e pesquisas, principalmente, sobre Epistemologia e Filosofia da Ciência voltados para o \ndesenvolvimento de ciência avançada, bem como em tecnologias inovadoras para ferramentas cognitivas e computacionais\n(compartilhamento de conhecimento), através de Ontologias, Taxonomias, Aprendizado de Máquina e \nProcessamento de Linguagem Natural.\n\ne-mail: ivo@coc.ufrj.br',
#   '000600000990',
#   '2012',
#   '2017',
#   '769300000008',
#   '2017',
#   '',
#   '000200000993'],
#  ['97916965255705',
#   '26022018',
#   'Doutor em Ciência da Computação pela Universidade Federal de Campina Grande (2015). Em 2012, por meio do Programa Probral, realizou atividades no KIT (Karlsruher Institut für Technologie), localizado na Alemanha, como parte do doutorado sanduíche. Mestre em Ciência da Computação pela Universidade Federal de Campina Grande (2010). Possui graduação em Ciência da Computação na mesma (2007). Tem experiência na área de Ciência da Computação, com ênfase em Hardware (Microeletrônica). Ex-membro do Brazil-IP. Ex-membro do programa CI-Brasil, trabalhou em projetos de Microeletrônica por mais de 5 anos. Foi integrante do CETENE (Centro de Tecnologias Estratégicas do Nordeste) por quase 5 anos, trabalhando em projetos de Microeletrônica. Atualmente é professor Adjunto A-1 na Universidade Federal Rural do Semi-Árido (UFERSA), Campus de Pau dos Ferros.',
#   '446900000000',
#   '2011',
#   '2015',
#   '769300000008',
#   '2017',
#   '',
#   ''],
#  ['43377806715007',
#   '26032017',
#   'Possui doutorado(2016) e mestrado em ciência da computação (2011) pela Universidade Federal de Minas Gerais e graduação em ciência da computação (2008) pela Universidade Estadual de Santa Cruz. Possui experiência na área de ciência da computação, com ênfase em Machine learning, Processamento Digital de Imagens e Algoritmos Evolucionários, atuando principalmente nos seguintes temas: Inferência Causal, Análise de Redes Sociais, Compressão de Imagens Digitais, Sumarização Automática de Vídeos e Algoritmos Baseados em Colônia de Formigas.',
#   '033300000002',
#   '2012',
#   '2016',
#   '769300000008',
#   '2017',
#   '',
#   ''],
#  ['22110232147076',
#   '28022018',
#   'Bacharel em Ciências da Computação pela Universidade Federal do Ceará (2003), mestre em Ciências da Computação pela Universidade Federal do Ceará (2005) e doutor em Ciência da Computação pela Universidade Federal do Ceará (2010). Tem experiência na área de Ciência da Computação, com ênfase em Visão Computacional, Jogos Digitais e Computação Gráfica. Atuando principalmente nos seguintes temas: Visão Computacional, Machine Learning, Segurança da Informação, Processamento Digital de Imagens, Realidade Virtual, Game Engines, Detecção de Colisões e Processamento de Cenas Tridimensionais.',
#   '008900000002',
#   '2005',
#   '2010',
#   '769300000008',
#   '2017',
#   '',
#   '008900000002'],
#  ['10659969702455',
#   '18022018',
#   'Possui doutorado em Engenharia Sistemistica e Informática pela Università degli Studi di Roma La Sapienza (1999), Itália,  mestrado em Engenharia Elétrica pela Pontifícia Universidade Católica do Rio de Janeiro (1988), pósdoutorado na Universitat Autónoma de Barcelona, Espanha, 2011, graduação em Engenharia Mecânica pela Universidade Nacional de Colômbia (1982), graduação em Engenharia Eletrônica pela Pontifícia Universidade Javeriana de Colômbia (1983),. Trabalhou na IBM como pesquisador do centro cientifico em RJ-Brazil. Trabalhou na Quadrics na área de supercomputação em Roma, Itália. Atualmente é professor associado da Universidade Federal de Mato Grosso do Sul. Tem experiência na área de Engenharia Eletrônica e Engenharia da Computação, com ênfase em Metodologia e Técnicas da Computação, atuando principalmente nos seguintes temas: circuitos digitais binários e de múltiplos valores, processamento de sinais e em álgebras de Clifford, computação de alto desempenho, computação paralela, processamento estereoscópico.',
#   '545500000001',
#   '1995',
#   '1999',
#   'J1QY00000001',
#   '2010',
#   '2011',
#   '087000000006'],
#  ['23809873085852',
#   '11102016',
#   'Possui Bacharelado em Informática pela Universidade Federal do Rio de Janeiro (1999), Mestrado (2001) e Doutorado (2005) em Engenharia de Sistemas e Computação pela COPPE/UFRJ. De fevereiro de 2004 a junho de 2005 esteve na Universidade de Stuttgart na Alemanha executando parte de seu doutorado através de um programa sanduíche. Desempenhou as funções de gerente de projeto e analista de sistemas em instituições públicas como o Centro de Catalogação das Forças Armadas e o Departamento de Abastecimento da Marinha do Brasil. Atualmente é professor adjunto do quadro permanente do Departamento de Ciëncias da Computação do Instituto de Computação na Universidade Federal Fluminense (UFF). Tem experiência na área de Ciência da Computação, com ênfase em Banco de Dados, atuando principalmente nos seguintes temas: Model Driven Architecture (MDA), aproximação geométrica, banco de dados espaciais, junção espacial, banco de dados e frequent itemsets.',
#   '020200000009',
#   '2001',
#   '2005',
#   '000300000995',
#   '2009',
#   '2012',
#   '000500000000'],
#  ['29233355476625',
#   '31122017',
#   'Professor Emérito da UFMG. Associado da Sociedade Brasileira de Computação. \n\nPossui graduação em Engenharia Química pela Escola de Engenharia (1971), mestrado em Informática pela Pontifícia Universidade Católica do Rio de Janeiro (1975) e doutorado em Ciência da Computação - University of California, Los Angeles (1981). Professor Titular da UFMG Aposentado. Professor Emérito da UFMG. Tem experiência na área de Ciência da Computação, com ênfase em Linguagens de Programação e Engenharia de Software, atuando principalmente nos seguintes temas: compiladores, métricas de software, modularidade e semântica formal. Coordenador do Curso de Pós-Graduação Lato Sensu em Informática da UFMG (1988-1999). Chefe do Departamento de Ciência da Computação da UFMG (1987-1989, 2000-2002, 2009-2011, 2011-2013). Coordenador do Bacharelado em Ciência da Computação da UFMG (1981-1983). Coordenador do Curso de Pós-Graduação em Ciência da Computação da UFMG (1983-1985, 1991-1993). Coordenador da Área de Ciência da Computação na CAPES (1995-1997). Coordenador Adjunto da Área de Ciência da Computação na CAPES (1993-1995). Coordenador da Câmara de Ciências Exatas e dos Materiais da Fapemig (10/2004-02/2005).\nRecebeu o Prêmio Nacional de Informática, Categoria Software, em 1988, patrocinado pelo Ministério de Ciência e Tecnologia, Modata e Fundação Roberto Marinho, e o prêmio Newton Faller da SBC (2009). Coordenador do XI Seminário Integrado de Software e Hardware da SBC (1984). Coordenador do V Simpósio Sobre Desenvolvimento de Software Básico da SBC (1985). Coordenador do V Simpósio Brasileiro de Engenharia de Software (1990). Coordenador da Comissão Especial de Engenharia de Software da SBC (1990-1991). Coordenador do I Simpósio Brasileiro de Linguagens de Programação (1996). Coordenador da Comissão Especial de Linguagens de Programação da SBC (2007-2008). Conselheiro da Sociedade Brasileira de Computação (SBC) (1985-1989, 1991-1993, 1997-2001, 2007-2011, 2017-2021). Diretor de Educação da SBC (1989-1991, 1993-1995. 1995-1997). Diretor de Regulamentação da Profissão da SBC (2001-2007). Diretor de Relações Profissionais da SBC (2011-2013, 2013-2015, 2015-2017). Presidente da Comissão de Ética da SBC (2012-2015).',
#   '000200000993',
#   '1977',
#   '1981',
#   '000300000995',
#   '2009',
#   '2012',
#   '033300000002'],
#  ['26358605322965',
#   '13012018',
#   'PhD em Finanças Computacionais pela Univeristy of Essex. Mestre em Economia pela Universidade Federal do Rio Grande do Sul, UFRGS. Graduado em Economia pela Universidade Estadual de Campinas, UNICAMP. Professor Adjunto do Departamento de Engenharia de Produção, Escola de Engenharia Industrial Metalúrgica de Volta Redonda, Universidade Federal Fluminense, UFF. Pesquisa interdisciplinar que abrange a aplicação de Ciência de Dados e Inteligência Artificial em mais de uma área de Economia e Finanças. Com colaboradores em disciplinas de diferentes áreas de conhecimento, trabalha em duas direções diferentes. A primeira direção é a simulação de modelos baseados em agentes de sistemas complexos como, por exemplo, sistemas econômicos e mercados financeiro; e a segunda direção é a análise de uma quantidade massiva de dados, denominados big data, para propor diferentes abordagens para responder a questões econômicas e financeiras.',
#   '129800000000',
#   '2009',
#   '2013',
#   '129800000000',
#   '2013',
#   '2014',
#   '000500000000'],
#  ['54585240202717',
#   '09032018',
#   'Possui graduação em Odontologia (2001), graduação em Ciência da Computação (2006) ambas pela Universidade de Brasília, mestrado em Ciencia y Tecnología Informática com foco em Inteligência Artificial pela Universidad Carlos III de Madrid (2009) e Doutorado em Informática pela Universidade de Brasília (2015) com período sanduíche na Universidade de York (Reino Unido). Tem experiência na área de Ciência da Computação, com ênfase em Inteligência Artificial, atuando principalmente nos seguintes temas: otimização multiobjetivo, computação bioinspirada, planejamento de conservação, bioinformática, modelagem de processos.',
#   '024000000008',
#   '2010',
#   '2015',
#   '129800000000',
#   '2013',
#   '2014',
#   '024000000008'],
#  ['33981436042117',
#   '05042018',
#   'Ricardo Massa Ferreira Lima obteve o título de Doutor em Ciência da Computação pela UFPE em 2000. Graduou-se (1993) e concluiu o mestrado (1994) em Ciência da Computação pela UFPE. Fez pós-doutorado (2001-2002) no grupo de Métodos Formais da Chalmers University of Technology, Suécia.  Atualmente é Professor Adjunto em regime de Dedicação Exclusiva da UFPE, onde exerce o cargo de Vice-Coordenador do Programa de Pós-Graduação em Ciência da Computação (nível 6 - Capes). É Chair do Comitê de Programa do SBLP`2010. Faz parte do Comitê de Programa do SBLP desde 2003. É membro do Conselho Editorial do International Journal of Services Operations and Informatics (IJSOI). É membro da SBC desde 1995 e membro da ACM desde 1999. \nSeus interesses em pesquisa são: \n1) modelagem e avaliação de sistemas dinâmicos de eventos discretos usando redes de Petri; \n2) implementação e otimização de compiladores. \nNo item (1) tem investigado os seguintes temas: \n1.a) modelagem e avaliação da logística de transporte e armazenamento de produtos acabados usando redes de Petri estocásticas;\n1.b) modelagem e avaliação de desempenho de processos de negócio usando redes de Petri; \n1.c) uso de redes de Petri para a modelagem, avaliação e síntese de código para sistemas embarcados de tempo real e com restrições de consumo de energia;\n1.d) mineração de processos para modelagem e avaliação de processos de negócio usando modelos em redes de Petri; \n1.e) modelagem e avaliação de desempenho de web services usando redes de Petri estocásticas. \nNo item (2) tem investigado os seguintes temas: \n2.a) desenvolvimento de um compilador baseado em programação orientada a aspectos para a linguagem JML (Java Modeling Language); \n2.b) otimização de compiladores para redução do consumo de energia em sistemas de tempo real.',
#   '002100000009',
#   '1995',
#   '2000',
#   '000500000999',
#   '2001',
#   '2002',
#   '002100000009'],
#  ['29796450556482',
#   '19012018',
#   'possui graduação em Engenharia Elétrica pela Universidade Federal de Santa Maria (1995), mestrado em Ciência da Computação pela Universidade Federal do Rio Grande do Sul (1997) e doutorado em Ciências da Computação outorgado conjuntamente pela Universidade Federal do Rio Grande do Sul e pela Technische Universitat Darmstadt, Alemanha (2003). Atualmente é professor do Departamento de Ciência da Computação na Universidade de York, no Reino Unido. Anteriormente, foi pesquisador sênior no Instituto de Sistemas Microeletrônicos da Technische Universitat Darmstadt. Tem experiência nas áreas de Ciência da Computação e Engenharia Elétrica, com ênfase em sistemas de computação e projeto de hardware, atuando principalmente nos seguintes temas: modelagem e avaliação de sistemas embarcados, sistemas multiprocessados on-chip (MPSoC), sistemas distribuídos e redes de sensores.',
#   '000100000991',
#   '2000',
#   '2003',
#   '000500000999',
#   '2001',
#   '2002',
#   '128000000007'],
#  ['84145280240578',
#   '15022018',
#   'Doutora em Informática Aplicada pela Pontifícia Universidade Católica do Paraná - PUCPR (2018). Mestre em Informática Aplicada pela mesma Universidade (PUCPR, 2011). Especialização em Projeto e Desenvolvimento de Sistemas Baseados em Objetos para Ambiente Internet pela UTFPR (2005). Graduação em Sistemas de Informação (2004). Professora Efetiva do Magistério Superior e Coordenadora do Curso de Bacharelado em Ciência da Computação da Universidade Tecnológica Federal do Paraná - UTFPR, Câmpus Santa Helena. Interesse de pesquisa nas áreas de Visão Computacional/Processamento de Imagens/Reconhecimento de Padrões, Computação Gráfica/Realidade Virtual e Desenvolvimento Web.',
#   '020700000008',
#   '2015',
#   '2018',
#   '000500000999',
#   '2001',
#   '2002',
#   '198100000000'],
#  ['31705260681319',
#   '28112017',
#   'Graduação em Agronomia pela Universidade Federal do Paraná (1984). Mestrado em Fitotecnia pela Universidade de São Paulo (1997). Doutorado em Fitotecnia pela Universidade de São Paulo (2006) e doutorando em Economia pelo Instituto de Economia da Unicamp. Pesquisador da Empresa Brasileira de Pesquisa Agropecuária desde 1989 com experiência na área de agronomia e ênfase em: i) tecnologia de sementes e mudas, ii) modelagem para previsão de clima e do desenvolvimento de plantas com aplicação na previsão de safras, iii) transferência de tecnologia e iv) negociação de tecnologias. Atualmente desenvolve trabalhos em socioeconômica na Secretaria de Inteligência e Macroestratégia da Embrapa com ênfase em gestão integrada do risco agrícola, bioenergia, desenvolvimento regional, comercio agricola internacional e cenários para agricultura.',
#   '007900000004',
#   '2004',
#   '',
#   '000500000999',
#   '2001',
#   '2002',
#   '009200000008'],
#  ['67454249660429',
#   '22092014',
#   '',
#   '011100000008',
#   '1995',
#   '1999',
#   '000500000999',
#   '2001',
#   '2002',
#   '032600000000'],
#  ['31046457146533',
#   '23022018',
#   'Danielli Araújo Lima received a B.Sc., M.Sc. and Ph.D. degree in Computer Science at the National University of Uberlândia, Brazil, in 2010, 2012 and 2017, with their respective emphases: cryptography, artificial intelligence and robotics. She is a full-time professor at the Federal Institute of Triangulo Mineiro, Campus Patrocínio and teaches courses in the areas of discrete mathematics, procedural programming and computational intelligence. She is currently specializing in Analysis and Development of Systems Applied to Business Management Course with emphasis on Software Engineering at the Federal Institute of the Triângulo Mineiro, Campus Uberlândia. At the same time she is reviewer of International Journal of Robotic Engineering and Advances in Science, Technology and Engineering Systems Journal. Her research interest is in the theory of cellular automata and its applications including encryption and complex systems modeling. Has experience in Computer Science, focusing on Artificial Intelligence, Cryptography, and Bio-Inspired Computation, acting on the following subjects (main keywords): Cellular Automata, Stochastic Models for Interdisciplinary Problems (Pedestrian Dynamics, Biological and Physical Applications, Ants), Robots Control (Surveillance and Search and Rescue tasks, Mobile Cyber-Physical Systems, Collective Intelligence, Artificial Neural-nets), Chaos and Dynamical Systems, Graphs, Queues and Computer Theory, Cryptography and Image Processing, Petri-Nets Modelling, Multi-Objective Searching Problems (Tabu Search, Particle Swarm Optimization, Ants Colony Optimization, Artificial Life), Parallel Solving Problems (Multi-Agent Systems, Natural Computing, Evolutive Computing and Genetic Algorithms, Local and Global Search), Automatic Planning, Algorithms Analysis.',
#   '001500000008',
#   '2012',
#   '2017',
#   '000500000999',
#   '2001',
#   '2002',
#   '520900000003'],
#  ['69944592699552',
#   '21092017',
#   'Engenheiro de Computação pela Universidade Federal do Rio Grande (FURG), sendo responsável pela visão computacional do time de futebol de robôs campeão da Latin American Robotics Competition. Possui doutorado em Visão Computacional pela Universidade Federal do Rio Grande do Sul (UFRGS), tendo trabalhado nas áreas de segmentação de pessoas para video conferência e geração de vistas sintéticas utilizando múltiplas câmeras em conjunto com a Hewlett Packard Palo Alto como pesquisador. \n\nAtualmente CTO e co-fundador da Meerkat Vision Ltda, atuando na pesquisa e desenvolvimento de novas tecnologias e produtos, tais como Reconhecimento Facial, ALPR e OCR de documentos. Possui amplos conhecimentos de otimização, com experiência em portar eficiente para diversas plataformas como Android, iOS e Raspberry Pi. Fluente em inglês.',
#   '019200000005',
#   '2011',
#   '2015',
#   '000500000999',
#   '2001',
#   '2002',
#   ''],
#  ['47384210554210',
#   '03042018',
#   'Possui Doutorado em Ciência da Computação pela Universidade Estadual de Campinas - UNICAMP (2006), Mestrado em Ciência da Computação pela Universidade Estadual de Campinas - UNICAMP (2002) e Graduação de Bacharelado em Informática pela Universidade Estadual de Ponta Grossa (1999). Atualmente é Professor Permanente do Programa de Doutorado/Mestrado em Ensino de Ciências e Matemática da Universidade Cruzeiro do Sul (São Paulo, SP), Professor da Universidade Nove de Julho (UNINOVE) e do Centro Universitário Anchieta - UNIANCHIETA (Jundiaí, SP). Tem experiência na área de Ciência da Computação, com ênfase em Interação Humano-Computador (IHC) e Engenharia de Software, atuando principalmente nos seguintes temas: desenvolvimento web, design e avaliação de interfaces, sistemas de informação geográfica, geoprocessamento, análise de sistemas, UML, UP, ensino-aprendizagem de tecnologias e matemática, conteúdos digitais interativos, objetos de aprendizagem, ambientes virtuais e colaborativos, jogos para o ensino, etc.',
#   '007900000004',
#   '2002',
#   '2006',
#   '000500000999',
#   '2001',
#   '2002',
#   '807700000001'],
#  ['85528501919153',
#   '23082016',
#   'Possui graduação em Engenharia Elétrica Ênfase Sistemas e Computação pela Universidade do Estado do Rio de Janeiro (1984), mestrado em Engenharia Elétrica pela Universidade Federal do Rio de Janeiro (1989) e doutorado em Engenharia Elétrica pela Universidade Federal de Santa Catarina (1998). Foi professor titular da Universidade do Sul de Santa Catarina até 2008. É pesquisador ad hoc da Empresa de Pesquisa Agropecuária e Extensão Rural de Santa Catarina S.A. Tem experiência na área de Engenharia Elétrica, com ênfase em Sistemas de Telecomunicações, atuando principalmente nos seguintes temas: processamento de imagens, antenas, prospecção petrolífera, reconstrução de imagens e tomografia. Atua na área de Gestão da Tecnologia da Informação desde 1995.\nReformulou do Projeto Pedagógico do Curso de Engenharia Telemática da UNISUL. *******English version follows*******\n\nHon. Amb. Gov. Dr. Eliezer Pereira Lopes, DG., MOIF, LFIBA, AIOM. Researcher, Consultant. Education: D.Sc. Electrical Engineering and Information Systems, Santa Catarina Federal University, Brazil, 1998; B.Ed. 1992, System Engineer (Electrical and System Engeneering) 1984, Rio de Janeiro State university, Brazil, 1984; M.Sc. (Electrical Engineering) 1989; Postgraduate Studies in Telecommunications Engineering (Electrical Engineering) 1985, Rio de Janeiro Federal University, Brazil; Proficiency in English Decree, University of Cambridge, England/Brazilian Society of English Culture, Rio de Janeiro, Brazil, 1980. Career: Telecommunications Researcher 2001 to present, Consultant on Higher Atmospheric Discharges and Weather Radar 1999 to present, South Santa Catarina University. Organizational Memberships: Order of International Fellowoship, 2006 to present, International Biographical Association (life fellow, 2006 to present), Brazilian Society of Geophysics, 1996 to 2011. Creative Works: "A Computer Code for Aerial Magnetic Soundings of Layered Media", Sensing and Imaging, 2010; "Radar observations of electrical atmospheric discharges occurring above the altitude of 20 km", Electrical Engeneering, 2004; "Assessing the Influence of the Ground-air Interface on Polarimetric Borehole-Radar-Data," Revista Brasileira de Geofísica, 2000; "Segmentation Tomography" 1998, "Multiplicative Version of the Dines and Lytle Algorithm" 1997, Electronics Letters, United Kingdom; "Robust Nonlinear Inversion of Wave-Tilt Data," Inverse Problems, United Kingdom, 1998: Lecturer: Telecommunications Theory, Telecommunications Laboratory, Control Systems Theory and Lab, Digital Communications Theory, Digital Communications Laboratory, Advanced Mathematics for Engineering, Advanced Mathematics for Information Systems, Electromagnetic Physics; Contributor to Professional Journals, Brazilian Geophysics Society, Institute of Electrical Engineers, others; Research on Electromagnetic Geophysical Tomography for Oil Exloration Industries and Neural Radar Probing of Stratified Media; Designer, Artificial Intelligence Systems for Issuing Alerts to River Floods and Nowcasting Systems for Automatically Detecting Hazardous Weather Conditions to Specific Crops; Numerous others; Personal Interests include: Travelling, Swimming, Reading, Listening to Classical Music and Hiking. Personal Philosophy: Faith, Perseverance and Tranquility. Personal email: eellpp76@gmail.com. Mobile number (Brazil): 5521973731163. Office Address: Eliezer P. Lopes Rua(Street) Guilherme da Silva Lopes, 2079. CEP (ZIP Code) 25035-200 Bairro(District) Villa Leopoldina. Cidade (City) Duque de Caxias. Estado(State): Rio de Janeiro. Brazil.',
#   '004300000009',
#   '1994',
#   '1998',
#   '000500000999',
#   '2001',
#   '2002',
#   '822900000009'],
#  ['16513273272803',
#   '05042018',
#   'Pós-Doutorado em Saúde Coletiva FCM-UNICAMP/FAPESP. Doutor em Saúde Coletiva pela FCM-UNICAMP. Graduação em Tecnologia Em Processamento de Dados pela Faculdade de Tecnologia de São Paulo (1993), Mestrado em Saúde Coletiva pela Universidade Estadual Paulista Júlio de Mesquita Filho (2006). Pesquisador do Laboratório de Análise Espacial de Dados Epidemiológicos - epiGeo, Faculdade de Ciências Médicas da UNICAMP. Tem experiência na área de Ciência da Computação, com ênfase em Analise e Desenvolvimento de Sistemas de Informação, atuando principalmente nos seguintes temas: distribuição espacial de risco, estudos caso-controle.',
#   '001400000995',
#   '2006',
#   '2008',
#   '007900000004',
#   '2008',
#   '2011',
#   '001400000995'],
#  ['83781586520627',
#   '15032018',
#   'Possui graduação em Ciências da Computação pela Universidade Federal de Santa Catarina (2002), mestrado em Ciências da Computação pela Universidade Federal de Santa Catarina (2005) e doutorado em Ciências Naturais (Ciências da Computação) pela Westfälische Wilhelms-Universität Münster - Alemanha (2010). Tem experiência na área de Ciência da Computação, com ênfase em Processamento Digital de Imagens, Reconhecimento de Padrões, Métodos Numéricos e Visão Computacional. Atualmente é professor Adjunto da Faculdade de Computação da Universidade Federal de Uberlândia.',
#   'IZ9A00000001',
#   '2007',
#   '2010',
#   '007900000004',
#   '2008',
#   '2011',
#   '001500000008'],
#  ['44685237701056',
#   '12032018',
#   'Possui graduação em Sistemas de Informação pela Faculdade Michelangelo/Instituto Rui Barbosa do Brasil (2005). Atualmente é teste - CTIS Tecnologia S.A. Tem experiência na área de Ciência da Computação, com ênfase em Sistemas de Informação.\n\nhttp://www.cnpq.br/',
#   '024000000008',
#   '2005',
#   '2006',
#   '024000000008',
#   '2009',
#   '2010',
#   '000600000990'],
#  ['71119715272492',
#   '19032018',
#   'É Doutor em Ciências da Computação pela Universidade de São Paulo (USP), Mestre em Ciência da Computação pela Universidade Federal de Pernambuco (UFPE) e bacharel em Ciências da Computação pela Universidade Federal de Alagoas (UFAL). Atualmente é professor de magistério superior no Departamento de Informática da Universidade Tecnológica Federal do Paraná (UTFPR), Campus Curitiba. Tem experiência na área de Ciência da Computação, com ênfase em Engenharia de Software (métodos ágeis) e Inteligência Artificial (Lógica Aplicada à Computação: tablôs, provadores automáticos de teoremas e lógicas paraconsistentes). Desenvolveu, junto com Marcelo Finger, o KEMS, um provador de teoremas multi-estratégia. Passou um ano sabático participando do grupo de pesquisas Realsearch, coordenado pela professora Laurie Williams, na North Carolina State University.',
#   '006700000002',
#   '2003',
#   '2007',
#   '535100000007',
#   '2014',
#   '2015',
#   '198100000000'],
#  ['06051248911331',
#   '15022008',
#   '',
#   '542000000008',
#   '1992',
#   '1995',
#   '535100000007',
#   '2014',
#   '2015',
#   '542000000008'],
#  ['88738440986018',
#   '14072017',
#   'Doutor em Bioinformática pela UFMG.\nEspecialista em Administração em Redes Linux pela UFLA.\nBacharel em Física pela UFMG.',
#   '033300000002',
#   '2007',
#   '2012',
#   '033300000002',
#   '2015',
#   '2015',
#   ''],
#  ['11562366111272',
#   '29032018',
#   'Possui bacharel em Matemática pela Universidad Nacional San Luis Gonzaga-Peru (2008), mestre e doutor em Engenharia Mecânica pela Universidade Federal de Pernambuco (2012 e 2016, respectivamente). Atualmente é Professor Adjunto na Universidade Federal de Pernambuco-UFPE. Tem experiência em equações diferenciais parciais, analise numérico, método de volumes finitos, CFD, simulação numérica e na docência.',
#   '002100000009',
#   '2012',
#   '2016',
#   '033300000002',
#   '2015',
#   '2015',
#   '002100000009'],
#  ['87804302005744',
#   '19012018',
#   'Coordenador do Programa de Pós-Graduação em Modelagem Computacional em Ciência e Tecnologia (PPGMC) da Universidade Estadual de Santa Cruz (UESC), lotado no Departamento de Ciências Exatas e Tecnológicas - área de Computação.\n\nDoutor e Mestre em Modelagem Computacional pelo Instituto Politécnico da Universidade do Estado do Rio de Janeiro (IPRJ/UERJ), Bacharel e Licenciado em Matemática pela Universidade Federal Rural do Rio de Janeiro (UFRRJ).\n\nAtualmente, coordenador da regional (Bahia - Alagoas - Sergipe) da Sociedade Brasileira de Matemática Aplicada e Computacional, colaborador em grupo de pesquisa da Universidade do Estado do Rio de Janeiro, avaliador ad hoc do Instituto Nacional de Estudos e Pesquisas Educacionais Anísio Teixeira, colaborador da Universidade Federal do Rio de Janeiro. Tem experiência na área de Matemática, com ênfase em Análise Numérica, atuando principalmente nos seguintes temas: modelagem computacional, modelagem de problemas biológicos, e Modelagem de Métodos numéricos para o transporte de nêutrons.',
#   '032600000000',
#   '2002',
#   '2007',
#   '033300000002',
#   '2015',
#   '2015',
#   '363100000000'],
#  ['95382890755450',
#   '16022011',
#   'Possui mestrado em física teórica - Université de La Méditerranée - Aix Marseille II (2005) e doutorado em  física teórica e matemática - Université de La Méditerranée - Aix Marseille II (2008). Tem experiência na área de Matemática, com ênfase em Física Matemática',
#   '132300000000',
#   '2005',
#   '2008',
#   '033300000002',
#   '2015',
#   '2015',
#   ''],
#  ['44387433155250',
#   '17032018',
#   'É bacharel em Ciência da Computação pela Universidade de Caxias do Sul (2007). Possui mestrado (2012) e doutorado (2016) em Inteligência Artificial pela Universidade Federal do Rio Grande do Sul . Atualmente, é pesquisador no grupo de recursos naturais da IBM research Brazil. Tem experiência na área de Inteligência Artificial com ênfase em Engenharia do conhecimento e Engenharia de Ontologias. Também tem experiência no desenvolvimento de ontologias e sistemas baseados em conhecimento para o domínio da Geologia de Petróleo e desenvolvimento de padrões baseados em ontologias para a área de Robótica e Automação. Tem como principal interesse de pesquisa atual a investigação de abordagens cognitivamente inspiradas para representação de conhecimento e raciocínio e para interpretação inteligente de dados, em geral. Também tem interesse nas áreas de Modelagem conceitual, Sistemas baseados em conhecimento e aprendizado não supervisionado. Foi membro do Robotics and Automation Working Group (ORA WG) da IEEE, que desenvolveu o primeiro padrão baseado em ontologias para representação de conhecimento no domínio da robótica e automação. Também tem atuado como vice-chair do grupo de trabalho IEEE 1872.2 - Standard for Autonomous Robotics (AuR) Ontology, líder do sub-grupo de representação de conhecimento do grupo de trabalho IEEE 7007 - Ontological Standard for Ethically Driven Robotics and Automation Systems, e como colaborador do grupo de trabalho IEEE 1872.1 - Robot Task Representation. Também é coordenador da área de padronização do chapter do Sul do Brasil da IEEE Robotics and Automation Society. Atualmente também é membro do grupo de pesquisa "Sistemas de Computação para E&P de Petróleo", do grupo BDI (grupo de bancos de dados inteligentes da UFRGS) e é um dos colaboradores do grupo SERG (Semiotic Engineering Research Group).',
#   '019200000005',
#   '2012',
#   '2016',
#   '033300000002',
#   '2015',
#   '2015',
#   '516400000006'],
#  ['16546400683999',
#   '05062017',
#   'Possui graduação em Bacharelado em Ciência da Computação pela Universidade Estadual Paulista Júlio de Mesquita Filho - UNESP (1992), mestrado (1999) e doutorado (2007) em Ciência da Computação e Matemática Computacional pelo Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo - ICMC - USP. Atualmente é professora e pesquisadora da Faculdade de Tecnologia (FT) da Universidade Estadual de Campinas (UNICAMP). Tem experiência na área de Ciência da Computação, com ênfase em Banco de Dados, atuando principalmente nos seguintes temas: base de dados complexos, consultas por similaridade, modularização de bases de dados e evolução de bases de dados.',
#   '006700000002',
#   '2002',
#   '2007',
#   '033300000002',
#   '2015',
#   '2015',
#   '007900000004'],
#  ['57958225738520',
#   '15122017',
#   'Atualmente estudante de pós-doutorado no Departamento de Computação e Matemática da USP de Ribeirão Preto. Possui Doutorado em Ciência da Computação pela Universidade de São Paulo (2017), Mestrado em Ciência da Computação pela Universidade Federal de Pernambuco (2011), Graduação em Bacharelado em Sistemas de Informação pelo Centro Universitário do Estado do Pará (2008). Experiência nas áreas de Engenharia de Software e Inteligência Artificial, principalmente nas seguintes linhas: Teste de Software, Teste de Mutação, Algoritmos de Buscas e Meta-heurísticas. Utilizador de software livre e linguagem de programação Python.',
#   '006700000002',
#   '2012',
#   '2017',
#   '006700000002',
#   '2017',
#   '',
#   '006700000002'],
#  ['55233538172646',
#   '09012018',
#   'Possui graduação em Bacharelado em Ciência da Computação pela Universidade Federal do Piauí (UFPI) em 2006.2, obteve o título de Mestre em Engenharia Elétrica da Escola de Engenharia de São Carlos da Universidade de São Paulo (EESC/USP) em 2009, e de Doutor no Instituto de Ciências Matemáticas e de Computação também na Universidade de São Paulo (ICMC/USP) em 2014 na Área de Sistemas Evolutivos. De volta ao Piauí fez Pós-Doutorado na UFPI em 2016 em Reconhecimento de Padrões. Atualmente é professor concursado no Departamento de Computação da UFPI.',
#   '006700000002',
#   '2009',
#   '2014',
#   '032300000004',
#   '2015',
#   '',
#   '032300000004'],
#  ['00601083852823',
#   '02102017',
#   'Possui graduação em Estatística pela Universidade Federal do Espírito Santo (2003), mestrado em Estatística pela Universidade Federal de Minas Gerais (2005) e doutorado em Estatística pela Universidade de Lancaster (Inglaterra, 2010). Atualmente e´professor no Departamento de Estatística da Universidade Federal do Espírito Santo.',
#   '466600000000',
#   '2006',
#   '2009',
#   '032300000004',
#   '2015',
#   '',
#   ''],
#  ['40074731614629',
#   '14102004',
#   '',
#   '',
#   '1994',
#   '1997',
#   '032300000004',
#   '2015',
#   '',
#   '003100000007'],
#  ['46303577453043',
#   '28032018',
#   'Graduado em Bacharelado em Informática pela Universidade de São Paulo (USP) em 2009, concluiu o Mestrado em 2011 pelo Instituto de Ciências Matemáticas e de Computação da Universidade de São Paulo (ICMC-USP). Concluiu seu Doutorado na mesma instituição em 2015, seguindo a linha de pesquisa de Inteligência Computacional. Tem experiência na área de Ciência da Computação com ênfase em Sistemas de Apoio à Tomada de Decisão. Atuou como analista de sistemas nas empresas Hominiss Consulting e Cristal Computadores, além de ter ministrado aulas de informática. Atualmente é Professor Assistente Doutor na Faculdade de Ciências e Engenharia da Universidade Estadual Paulista (UNESP - Campus de Tupã). Atua principalmente nas áreas de Mineração de Dados e Aprendizado de Máquina. Tem interesse em Aprendizado Ativo e Semissupervisionado, Agregação de Classificadores e Agrupadores bem como em Computação Bioinspirada, Data Science e Big Data.',
#   '006700000002',
#   '2011',
#   '2015',
#   '032300000004',
#   '2015',
#   '',
#   '033000000007'],
#  ['35213619257246',
#   '27032018',
#   'Professor Adjunto da Universidade Federal do Maranhão (UFMA). Coordenador do Curso de Engenharia da Computação (UFMA) e Professor colaborador do Programa de Pós-Graduação em Ciência da Computação (PPGCC) da UFMA. Doutor em Neurociência (Neuroinformática / Neurociência Computacional) pela Universidade de Tübingen (Alemanha) & International Max Planck Research School for Cognitive and Systems Neuroscience (International Max Planck Research School for Neural Information Processing), Mestre em Engenharia Mecatrônica pela Universidade do Minho (Portugal) e Bacharel em Ciência da Computação pela Universidade Federal do Maranhão (UFMA) - Brasil.\nFormação ampla, em diferentes áreas de pesquisa, assim como uma formação internacional, em diversas universidades de diferentes países. \nTem experiência na área de Computação com ênfase em Inteligência Computacional, Robótica e Neurociência, atuando principalmente nos seguintes temas: Robótica Móvel e Autônoma, Robótica Educacional, Análise e Processamento de Dados e Sinais, Aprendizado de Máquina, Automação e Controle de Processos, Visão Computacional, Pesquisa Operacional - Otimização, Neurociência Computacional e Brain Computer-Interface (BCI).',
#   '139800000007',
#   '2012',
#   '2015',
#   '032300000004',
#   '2015',
#   '',
#   ''],
#  ['11303079806761',
#   '03062014',
#   'Possui graduação em  Automatique et Electronique Industrielle  pelo  Institut National des Sciences Appliquées  (1968), mestrado pela Université Toulouse III Paul Sabatier (1971) e doutorado em  Sciences  pela Université Toulouse III Paul Sabatier (1977). Atualmente é Pesquisador Titular do Instituto Nacional de Pesquisas Espaciais. Tem experiência na área de Ciência da Computação, com ênfase em Sistemas de Computação. Atuando principalmente nos seguintes temas: Processo de Difusão, Processo de Markov, Sistema Dinámico, Estimação de Densidade, Processamento de Imagens e Morfologia Matemática.',
#   '164000000003',
#   '1971',
#   '1977',
#   '032300000004',
#   '2015',
#   '',
#   '008700000009'],
#  ['01155355210327',
#   '01032018',
#   'Possui graduação em Ciências da Computação pela Universidade Federal de Santa Catarina (1996), mestrado em Engenharia Elétrica e Informática Industrial pela Universidade Tecnológica Federal do Paraná (1999) e doutorado em Engenharia Elétrica pela Universidade de São Paulo (2004). Atualmente é professor assistente doutor - ms3 da Universidade Estadual Paulista Júlio de Mesquita Filho. Tem experiência na área de Ciência da Computação, com ênfase em Redes de Computadores, atuando principalmente nos seguintes temas: modelagem matemática e computacional, desempenho e segurança de redes.',
#   '006700000002',
#   '2000',
#   '2004',
#   '079500000004',
#   '2004',
#   '2005',
#   '033000000007'],
#  ['05979228894386',
#   '09052016',
#   'Possui graduação em Análise e Desenvolvimento de Sistemas pela Faculdade de Filosofia Ciências e Letras de Caruaru - FAFICA (2008). Concluiu o mestrado na UFPE em 2010. Recentemente, concluiu o doutorado do curso de Ciência da Computação na UFPE (Universidade Federal de Pernambuco), atuando principalmente nos seguintes temas: redes de computadores, sistemas distribuídos, middleware e rede de sensores sem fio.\n\nAlguns códigos desenvolvidos podem ser encontrados no GitHub (https://github.com/antonio-damaso).',
#   '002100000009',
#   '2011',
#   '2016',
#   '079500000004',
#   '2004',
#   '2005',
#   ''],
#  ['37384367302439',
#   '22012016',
#   'Possui doutorado em Engenharia elétrica obtido em 1999 da Rheinisch-Westfälische Technische Hochschule Aachen com o assunto "Processamento Digital de Sinais para Alto-Falantes". Atualmente é especialista visitante na Divisão de Acústica do Instituto Nacional de Metrologia, Qualidade e Tecnologia. Tem experiência nas áreas de áudio profissional, acústica de salas, inteligibilidade de fala, eletrônica analógica e digital, desenho de placas multi-layer, programação de CPU (x86, FPU, MMX, SSE2), µC, DSP e CPLD, processamento digital de sinais, formatos de áudio digital para armazenamento e transmissão, medição de funções de transferência e de respostas impulsivas, geração de sinais de excitação de banda larga, alto-falantes, amplificadores de potência, sistemas de sonorização e calibração de microfones e de acelerômetros.',
#   '100800000001',
#   '1994',
#   '1999',
#   '079500000004',
#   '2004',
#   '2005',
#   '870100000004'],
#  ['60120644445370',
#   '20032018',
#   'Vanessa Braganholo é professora Associada do Instituto Computação da UFF. Possui graduação em Ciência da Computação (1998) pela UFRGS e doutorado (2004) em Ciência da Computação também pela UFRGS, com período de um ano de sanduíche na Universidade da Pennsylvania (EUA). Atuou como bolsista de pós-doutorado na Universidade Federal do Rio de Janeiro (COPPE) em 2005, e como professora visitante da New York University (NYU) por três meses em 2013. É bolsista de produtividade nível 2 do CNPq desde 2007 e foi Jovem Cientista do Nosso Estado (FAPERJ) (nov/2010-out/2013; nov/2013-out/2016). Atuou como vice-coordenadora do Programa de Pós-Graduação em Computação da UFF (out/2012-jun/2017). Possui diversas publicações em fóruns relevantes da área de banco de dados, como VLDB, ACM Transactions on Database Systems e SBBD. Sua tese de doutorado recebeu prêmio de 1o. lugar no Concurso de Teses e Dissertações da Sociedade Brasileira de Computação em 2005. É co-chair do VLDB DEMO 2018. Foi coordenadora da Comissão Especial de Banco de Dados em 2016, chair do comitê de programa do Simpósio Brasileiro de Banco de Dados 2015, co-chair do Comitê de Programa do SIGMOD DEMO 2015, co-chair do Student Session do Alberto Mendelzon International Workshop on Foundations on Data Management (AMW) 2012, chair do Comitê de Programa da trilha Core Database Foundations and Technology do Simpósio Brasileiro de Banco de Dados (SBBD) em 2011, Chair do Comitê de Programa do Workshop e-Science em 2010, Chair do Comitê de Programa da Sessão de Demos do SBBD em 2008 e Co-chair do Comitê de Programa do Workshop de Teses e Dissertações em Sistemas de Informação (WTDSI), também em 2008. Atualmente atua como editora associada do SIGMOD RECORD (desde 2011) e serve em diversos comitês de programa da área de banco de dados e eScience. Serviu como Editora Associada do Journal of Information and Data Management (JIDM) de 2012 a 2014. Tem atuado em comitês de programa de eventos ligados a Banco de Dados. Já coordenou diversos projetos de pesquisa aprovados por órgãos de fomento. Entre eles, cabe destacar: 2 Projetos Universais CNPq, 1 Projeto "Primeiros Projetos", 2 Projetos "Jovem Cientista do Nosso Estado FAPERJ". Tem experiência na área de Ciência da Computação, com ênfase em Banco de Dados e e-Science. Mais informações podem ser obtidas em http://www.ic.uff.br/~vanessa.<BR><BR>\n\nSeu nome era Vanessa de Paula Braganholo até 2006. <BR><BR>\n** Nome em citações: BRAGANHOLO, V. **',
#   '019200000005',
#   '2000',
#   '2004',
#   '020200000009',
#   '2005',
#   '2006',
#   '000500000000'],
#  ['49390900009593',
#   '03042018',
#   'Possui graduação em Tecnólogo em Processamento de Dados pela Universidade de Taubaté (1986), Mestrado em Computação Aplicada pelo Instituto Nacional de Pesquisas Espaciais (2002) e Doutorado em Sensoriamento Remoto pelo Instituto Nacional de Pesquisas Espaciais (2011). Atualmente é Tecnologista Senior do Instituto Nacional de Pesquisas Espaciais. Tem experiência na área de Ciência da Computação e Sensoriamento Remoto, atuando principalmente nos seguintes temas: processamento de imagens, sensoriamento remoto, séries temporais, ecossistemas tropicais e ciências ambientais, recursos florestais e sistemas computacionais.',
#   '008700000009',
#   '2006',
#   '2011',
#   '020200000009',
#   '2005',
#   '2006',
#   '008700000009'],
#  ['19007386914899',
#   '09032013',
#   '',
#   '139000000002',
#   '1992',
#   '1996',
#   '020200000009',
#   '2005',
#   '2006',
#   '080200000002'],
#  ['44423463893899',
#   '06122017',
#   'Professor universitário durante 38 anos, é Bacharel em Física (1972) e M.Sc. em Sistemas e Computação (1974) pela UFPB (1974) e Ph.D. em Systems Design (1978) pela University of Waterloo/Canadá (1978). Fez pós-doutorado em Inteligência Artificial, na Universidade Nova de Lisboa, Portugal, e tem cursos de especialização em Planejamento Estratégico (com Carlos Matos) e em Dinâmica dos Grupos (pela SBDG). No período de 1973 a 1998, foi Professor Adjunto na área de Ciência da Computação na Universidade Federal de Campina Grande (UFCG) e na Universidade de Brasília (UnB), período no qual (de 1981 a 1998) também foi Analista Senior de Ciencia e Tecnologia do CNPq. De 1998 a 2011 foi Professor Adjunto e Pesquisador na Universidade Católica de Brasília (UCB), no Mestrado em Gestão do Conhecimento e da Tecnologia da Informação. É coach ontológico certificado desde 1997, pela antiga The Newfield Group, em parceria com o Instituto Tecnológico de Estudos Superiores de Monterrey (ITESM). Atualmente é Diretor Executivo do Laboratório de Pesquisas sobre Conversas nas Organizações ? LabCon. Suas áreas de pesquisa hoje incluem: Aprendizagem Organizacional, Conversas nas Organizações, Coaching Ontológico - Pessoal, Executivo e Organizacional -, Gestão do Conhecimento e Desempenho de Equipes. Especificamente, no Labcon, dedica-se a desenvolver e disseminar a pesquisa e a aplicação prática do coaching e de competências conversacionais em instituições brasileiras.',
#   '134100000003',
#   '1975',
#   '1978',
#   '158800000003',
#   '1988',
#   '1988',
#   ''],
#  ['04347616155745',
#   '09042002',
# ...
#   '019200000005',
#   '1999',
#   '2004',
#   '',
#   '',
#   '',
#   '000600000001'],
#  ['70160002748982',
#   '04042018',
#   'Graduado em Engenharia da Computação pela Universidade São Francisco (2002) com especialização em Engenharia de Software (2005) e mestrado e doutorado em Engenharia Elétrica (2009, 2015) pela Universidade de São Paulo. Pós-doutorado no Center of Modeling Complex Interactions na Universidade de Idaho. Atualmente, professor na Brandenburg University of Technology na Alemanha. As áreas de interesse são Sistemas Multiagentes, Simulação Baseada em Agentes e Análise Estatística, em especial no desenvolvimento e uso de técnicas de modelagem baseada em agentes para o estudo dos efeitos do comportamento humano em sistemas socio-técnicos. É membro eleito do RoboCup Rescue Agent Simulation League Executive Committee.',
#   '006700000002',
#   '2010',
#   '2015',
#   '279300000003',
#   '2015',
#   '2017',
#   '054500000009'],
#  ['41174632142247',
#   '09022018',
#   'Possui graduação em Matemática pela Universidade Federal do Amazonas (2009), mestrado em Matemática pela Universidade Federal do Amazonas (2012) e doutorado em Matemática Aplicada com aplicações em Interação Humano-Computador pela Universidade de São Paulo (2016).',
#   '006700000002',
#   '2013',
#   '2016',
#   '279300000003',
#   '2015',
#   '2017',
#   ''],
#  ['11360838843470',
#   '26032018',
#   'possui doutorado em Ciência da Computação pela Universidade Federal da Bahia (2015), mestrado em Informática pela Universidade Federal de Campina Grande (2003), Especialização em Projeto de Desenvolvimento e Aplicações pela Unifacs (1999) e graduação em Tecnologia em Processamento de Dados pela Faculdade Ruy Barbosa (1995). Atualmente é professor adjunto da Universidade Estadual de Feira de Santana. Tem experiência na área de Ciência da Computação, com ênfase em Engenharia de Software, atuando principalmente nos seguintes temas: Gerência de Projetos, Processos de Desenvolvimento Ágeis, Orientação a Objetos e Engenharia de Software Experimental.',
#   '029100000000',
#   '2011',
#   '2015',
#   '279300000003',
#   '2015',
#   '2017',
#   '204400000003'],
#  ['60724492759410',
#   '28022007',
#   '',
#   '325100000007',
#   '2001',
#   '2006',
#   '279300000003',
#   '2015',
#   '2017',
#   '004700000006'],
#  ['35478936121854',
#   '15012018',
#   'Doutorado em Ciência da Computação (UFPE - 2016); Mestre em Ciência da Computação (UFPE - 2009) e Engenheira da Computação (UPE - 2006) . Atua como Líder Técnico no projeto CIn/Samsung da UFPE. Tem como áreas de interesse Mobilidade, Avaliação de Desempenho, Redes de Computadores, Sistemas Distribuídos, Engenharia de Software e Telecomunicações.',
#   '002100000009',
#   '2011',
#   '2016',
#   '279300000003',
#   '2015',
#   '2017',
#   '002100000009'],
#  ['98550954813139',
#   '02112017',
#   'got his Ph.D. in Computer Science in 2009 at École Polytechnique (France). Currently, Carlos is professor at ECT-UFRN.\nHis research interests are concurrency theory, formal methods and logic. He is also a member of the AVISPA research group.',
#   '162100000009',
#   '2006',
#   '2009',
#   '279300000003',
#   '2015',
#   '2017',
#   '033700000000'],
#  ['32116344380113',
#   '30042002',
#   '',
#   '127000000009',
#   '1982',
#   '1986',
#   '279300000003',
#   '2015',
#   '2017',
#   '020200000009'],
#  ['05648479653641',
#   '18112016',
#   'Atualmente é professora - Na escola estadual José Domingos Fraga',
#   '127000000009',
#   '1982',
#   '1986',
#   '279300000003',
#   '2015',
#   '2017',
#   'IX8Z00000008'],
#  ['32936069409933',
#   '05022018',
#   'Licenciada (2008) e Bacharel (2010) em Ciências Biológicas pela Universidade Federal Fluminense. Mestre em Ciências e Biotecnologia tendo desenvolvido um protótipo para o estudo de seleção alimentar em camundongos. Defendeu a tese no Programa de Pós-graduação em Ciências e Biotecnologia/UFF que teve como objetivo entender a modificação da homeostase intestinal durante a indução de inflamação intestinal crônica e como isso pode afetar o perfil da microbiota de camundongos. Embora o foco principal sejam as reatividades imunológicas, aspectos aplicados e o enfoque biotecnológico das aplicações possíveis fazem parte dos objetivos. Tem experiência com manipulação animal, bem como diversas técnicas in vitro, tais como técnicas imunológicas e de biologia molecular. Colabora com diversos grupos internos e externos para o desenvolvimento de trabalhos multidisciplinares.',
#   '000500000000',
#   '2013',
#   '2017',
#   '279300000003',
#   '2015',
#   '2017',
#   ''],
#  ['25623517319669',
#   '05112015',
#   'Licenciada (2008) e Bacharel (2010) em Ciências Biológicas pela Universidade Federal Fluminense. Mestre em Ciências e Biotecnologia tendo desenvolvido um protótipo para o estudo de seleção alimentar em camundongos. Defendeu a tese no Programa de Pós-graduação em Ciências e Biotecnologia/UFF que teve como objetivo entender a modificação da homeostase intestinal durante a indução de inflamação intestinal crônica e como isso pode afetar o perfil da microbiota de camundongos. Embora o foco principal sejam as reatividades imunológicas, aspectos aplicados e o enfoque biotecnológico das aplicações possíveis fazem parte dos objetivos. Tem experiência com manipulação animal, bem como diversas técnicas in vitro, tais como técnicas imunológicas e de biologia molecular. Colabora com diversos grupos internos e externos para o desenvolvimento de trabalhos multidisciplinares.',
#   '000400000997',
#   '1990',
#   '1995',
#   '127400000006',
#   '2008',
#   '2009',
#   '006700000002'],
#  ['82804646377460',
#   '01102017',
#   'Concluiu o doutorado em Engenharia de Produção na Universidade Federal de Santa Catarina em 1993. Atualmente é Professor Associado, do departamento de Engenharia do Conhecimento da Universidade Federal de Santa Catarina atuando no Bacharelado em Sistemas de Informação, no Programa de Pós-graduação em Engenharia e Gestão do Conhecimento e no Mestrado Profissional em Métodos e Gestão em avaliação. \nFoi na UFSC: Diretor do Departamento de Apoio à Pesquisa, Membro de conselho da Fundação de Amparo a Pesquisa e Extensão Universitária ? FAPEU, Coordenador do Curso de Pós-Graduação em Ciências da Computação, Representante dos Coordenadores dos Programas de Pós-Graduação Stricto Sensu do CTC na Câmara de Pós Graduação , representante da Câmara de Pos-graduação no Conselho Universitário, Diretor Técnico da Escola de Novos Empreendedores, Diretor Acadêmico do Campus de Ararangua, Chefe do Departamento de Engenharia do Conhecimento e Sub-Coordenador do Programa Pós-Graduação em Métodos e Gestão em Avaliação.\nConsultor ad hoc do CNPq, da Fundação de Amparo à Ciência e Tecnologia do Estado de Pernambuco - FACEPE, da Fundação de Amparo à Pesquisa do Estado da Bahia - FAPESB e da Fundação de Amparo à Pesquisa e Inovação do Estado de Santa Catarina ? FAPESC.\nTem experiência nas áreas de empreendedorismo e inovação, inteligência artificial, computação evolutiva, ensino à distância via web , engenharia do conhecimento onologias e linked data.',
#   '004300000009',
#   '1989',
#   '1993',
#   '127400000006',
#   '2008',
#   '2009',
#   '004300000009'],
#  ['46776718921674',
#   '13112017',
#   'Possui graduação em Matemática pela Universidade do Estado do Rio de Janeiro (2004), mestrado em Modelagem Computacional - Laboratório Nacional de Computação Científica (2007) e doutorado em Engenharia de Sistemas e Computação pela Universidade Federal do Rio de Janeiro (2010). Atualmente é professor da Universidade Federal do Ceará. Tem experiência na área de Matemática, com ênfase em Matemática Aplicada, atuando principalmente nos seguintes temas: pesquisa operacional, bioinformática, computação quântica e análise numérica.',
#   '020200000009',
#   '2007',
#   '2010',
#   '020200000009',
#   '2010',
#   '2010',
#   '008900000002'],
#  ['91084760973085',
#   '21072015',
#   'Possui graduação em Ciência da Computação pela Universidade Federal da Paraíba (2000), mestrado em Ciências da Computação pela Universidade Federal de Pernambuco (2004) e doutorado em Ciências da Computação pela Universidade Federal de Pernambuco (2011). Atualmente é professora adjunta I da Universidade Federal Rural de Pernambuco. Tem experiência na área de Ciência da Computação, com ênfase em Redes de Computadores e Sistemas Distribuídos, atuando principalmente nos seguintes temas: middleware, redes de sensores sem fio (rssf), gerência de recursos de rádio (rrm), redes heterogêneas (hetnet) e redes veiculares (vanets).',
#   '002100000009',
#   '2006',
#   '2011',
#   '020200000009',
#   '2010',
#   '2010',
#   '033800000001'],
#  ['67634017777916',
#   '19032018',
#   'Possui Graduação (2006) e Mestrado (2009) em Geofísica pelo Instituto de Astronomia, Geofísica e Ciências Atmosféricas (IAG) da Universidade de São Paulo (USP). Doutorado (2014) em Geofísica pela USP e Universidade de Liverpool (Inglaterra) e Pós-Doutorado em Electroscience Laboratory - ESL (The Ohio State University - OSU) e no IAG/USP. Tem experiência na área de Geociências, com ênfase em Geofísica Aplicada, atuando principalmente nos seguintes temas: GPR - Ground Penetrating Radar, Método Eletromagnético Indutivo (tempo e frequência) e Métodos Elétricos.',
#   '000200000993',
#   '2009',
#   '2014',
#   '006700000002',
#   '2016',
#   '2017',
#   ''],
#  ['17993003840757',
#   '04042013',
#   'Possui graduação em Engenharia eletrica pela Universidade Estadual de Campinas (1974), mestrado em Matemática Aplicada - Unicamp (1980) e doutorado em Engenharia Mecânica pela Universidade Estadual de Campinas (1989). Atualmente é consultor - Núcleo Softex Campinas e pesquisadora/ divisão de segurança e sistemas do Centro de Tecnologia da Informação Renato Archer - CTI. Tem experiência na área de Ciência da Computação, com ênfase em Segurança da Informação, atuando principalmente nos seguintes temas: qualidade de software, engenharia de software, qualidade de processos, método de avaliação. e sistema de gestão.\n\nAreas de interesse: Segurança da Informação, Metricas de Segurança, AHP',
#   '007900000004',
#   '1980',
#   '1989',
#   '006700000002',
#   '2016',
#   '2017',
#   '000800000994'],
#  ['02720619177278',
#   '08112015',
#   'É oficial da Marinha Mercante com graduação em Radiotecnia pela Escola Náutica Infante D. Henrique (1982).  Possui graduação em Engenharia Electrotécnica - Computadores, ramo de Hardware pelo Instituto Superior de Engenharia de Lisboa (1987) e graduação em Engenharia Informática pela Universidade Nova de Lisboa (1990). Possui mestrado em Informática pela Universidade Nova de Lisboa (1995) e doutorado em Engenharia Electrotécnica pela Universidade Nova de Lisboa (2004). Atualmente é coordenador do grupo de pesquisa Sistemas Indistriais do UNINOVA - Instituto de Desenvolvimento de Novas Tecnologias e professor da Universidade Nova de Lisboa, onde lecciona no departamento de Engenharia Electrotécnica da Faculdade de Ciências e Tecnologia. É revisor de projectos da União Europeia e tem participado na revisão de projectos de pesquisa das entidades científicas da Itália, Grécia, Chipre, Eslováquia e Portugal. Tem participado activamente em vários projectos de pesquisa da União Europeia nos vários programas quadro, FP5, FP6 e FP7. Tem coordenado a equipa local do UNINOVA nestes projectos desde 2004. Tem experiência na área de Engenharia Elétrica, com ênfase em Automação Eletrônica de Processos Elétricos e Industriais, atuando principalmente nos seguintes temas: multiagent systems, agile manufacturing, mobile robots, self-organisation e multi-agent systems.',
#   '158800000003',
#   '1999',
#   '2004',
#   '006700000002',
#   '2016',
#   '2017',
#   '158800000003'],
#  ['22973320203284',
#   '26032018',
#   'Graduado em Arquitetura e Urbanismo pelo Centro Universitário Moura Lacerda (1998), especialista em Design de Multimídia pela Universidade AnhembiMorumbi (2000) , mestre pelo programa de Pós-Graduação em Desenho Industrial - linha de pesquisa Planejamento de Produto - UNESP (2007) e doutor pelo Programa de Pós-Graduação da Faculdade de Engenharia, Arquitetura e Construção da UNICAMP (2015), na área de concentração Arquitetura, Tecnologia e Cidade - linha de pesquisa Metodologia e Teoria de Projeto e da Cidade, possui pesquisas relacionadas à utilização de tecnologias no processo de projeto, modelagem paramétrica, sistemas generativos de projeto, projetos bio-inspirados e fabricação digital. Atualmente é professor e pesquisador na Universidade Federal do Espírito Santo / UFES.',
#   '007900000004',
#   '2010',
#   '2015',
#   '006700000002',
#   '2016',
#   '2017',
#   '039200000000'],
#  ['70275195280528',
#   '07032018',
#   'Possui graduação em Engenharia de Computação pela Universidade Federal do Espírito Santo (1996), mestrado em Informática pela Universidade Federal do Espírito Santo (1999) e Doutorado em Informática na Educação pela Universidade Federal do Rio Grande do Sul (2011). Atua como professor do Mestrado Profissional em Ensino e suas Tecnologias, Mestrado Profissional em Educação Profissional e Tecnológica e Engenharia de Computação no IFF. Pesquisador do Núcleo de Pesquisa em Informática na Educação (NIE) do IFF. Possui experiência na área de Ciência da Computação, com ênfase em Informática na Educação, Engenharia de Software, Inteligência Artificial, atuando principalmente nos seguintes temas: desenvolvimento de software, mineração de textos, tecnologias digitais na educação, educação a distância, inteligência artificial aplicada à educação.',
#   '019200000005',
#   '2008',
#   '2011',
#   '006700000002',
#   '2016',
#   '2017',
#   '273000000009'],
#  ['03863569320581',
#   '12122017',
#   'Atualmente é professora no Instituto Federal de Educação, Ciência e Tecnologia de São Paulo, campus Piracicaba. É doutora em Engenharia da Computação (2012) pela Faculdade de Engenharia Elétrica e de Computação (FEEC) da Universidade Estadual de Campinas (UNICAMP). Mestre em Engenharia da Computação pela Universidade Estadual de Campinas (2007) e graduada em Tecnologia em Processamento de Dados pela Faculdade de Tecnologia de Americana (2004). Também atuou por nove anos na área de análise e desenvolvimento de sistemas.',
#   '007900000004',
#   '2008',
#   '2012',
#   '006700000002',
#   '2016',
#   '2017',
#   ''],
#  ['44195230407619',
#   '20032018',
#   'Possui graduação em Ciência da Computação pela Universidade do Oeste de Santa Catarina (2002), mestrado em Ciências da Computação pela Universidade Federal de Pernambuco (2004) e doutorado em Ciências da Computação pela Universidade Federal de Pernambuco (2008). Atualmente é Professor Associado do Centro de Informática da Universidade Federal de Pernambuco. Tem experiência na área de Ciência da Computação, atuando principalmente nos seguintes temas: redes neurais artificiais, nariz artificial, sistemas híbridos inteligentes, otimização global e artificial immune systems. Associado da Sociedade Brasileira de Computação (SBC).',
#   '002100000009',
#   '2004',
#   '2008',
#   '002100000009',
#   '2008',
#   '2009',
#   '002100000009'],
#  ['54338144161360',
#   '08032018',
#   'Gibeon Aquino holds a Ph.D. in Computer Science from the Federal University of Pernambuco (UFPE) - 2010, with the thesis in the area of Software Engineering. He has a background in Software Architecture, especially in Enterprise Information Systems and Mobile Applications. Before joining UFRN in August 2010, he worked at the Center of Studies and Advanced Systems of Recife (CESAR) as a Software Architect of several systems for more than ten years. His current research interest involves Mobile and Ubiquitous Computing, Internet of Things and Smart Cities. He teaches undergraduate and postgraduate courses including Mobile Programming, Software Configuration Management, and Software Architecture. Currently, he is the Head of Systems Division at UFRN, responsible for the development and maintenance of important systems like SIGAA, SIPAC, and SIGRH, which are used by several government organizations and public institutions in Brazil.',
#   '002100000009',
#   '2005',
#   '2010',
#   '002100000009',
#   '2008',
#   '2009',
#   ''],
#  ...]
